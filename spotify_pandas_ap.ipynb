# %%
# Dependencies and Setup
import numpy as np
import requests
import json
import time
import requests
import pandas as pd
from pandas.io.json import json_normalize
from pprint import pprint

# %%
#-------------------------------------------------
# # function to flatten json object

def flatten_json(y):
    out = {}
    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x
    flatten(y)
    return out
#---------------------------------------------------

# %%
# get top 100 playlist
url3 = "https://api.spotify.com/v1/playlists/4hOKQuZbraPDIfaGbM3lKI"
# get a song
url = "https://api.spotify.com/v1/audio-features/06AKEBrKUckW0KREUWRnvT"
headers = {'Accept': 'application/json', 'Content-Type' : 'application/json','Authorization': 'Bearer BQDksbT92O4rU8YihJzsCOUNGA-CWSgUdw1Do8lzbwGtt8uePUW32alHTgTABFUhT8Qra0NXmbQkpTxaKYtueNWwtTNbU8p8LhxG6HNBXZN6ONBHRsB0rTHC76zKqEltKZZzaVcYQaCY08GoIZZEiXMrNdOaf5okJJMGii5gZ1WO9ltMUTLDmaDRGyAZSBIHC6nWM2M25Jni2Yl1po6Rba0mhRjnNjpADy-feNfn4uR0GoRLRuItjDby3T2n3Zoqvq6z4BAB'}

# call api for top 100
request = requests.get(url3, headers=headers)
j_response = request.json()
print(json.dumps(j_response, indent=4, sort_keys=True))
# Out:
# {
#     "collaborative": false,
#     "description": "",
#     "external_urls": {
#         "spotify": "https://open.spotify.com/playlist/4hOKQuZbraPDIfaGbM3lKI"
#     },
#     "followers": {
#         "href": null,
#         "total": 18698
#     },
#     "href": "https://api.spotify.com/v1/playlists/4hOKQuZbraPDIfaGbM3lKI",
#     "id": "4hOKQuZbraPDIfaGbM3lKI",
#     "images": [
#         {
#             "height": 300,
#             "url": "https://i.scdn.co/image/d5905c3899a14a48bd67d4ccfdea5ec14de74947",
#             "width": 300
#         }
#     ],
#     "name": "Top 100 tracks currently on Spotify",
#     "owner": {
#         "display_name": "Spotify",
#         "external_urls": {
#             "spotify": "https://open.spotify.com/user/spotify"
#         },
#         "href": "https://api.spotify.com/v1/users/spotify",
#         "id": "spotify",
#         "type": "user",
#         "uri": "spotify:user:spotify"
#     },
#     "primary_color": null,
#     "public": false,
# ...

# %%
#--------------------------------------------------- 
# f = flatten_json(j_response)
# data = pd.DataFrame(json_normalize(f))
# # make rows into columns so it's easier to read
# data = data.transpose()
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#    print(data)
# # First element is general information, second is countries themselves
# val = countries_response[1][26]['name']
# #print(val)
#---------------------------------------------------

# %%
track_list = []

for rec in j_response['tracks']['items']:
    for x in range(100):
        if rec is not None:
            val = rec['track']['id']
            if not track_list.count(val):
                track_list.append(val)
#                 print(val)

# %%
for track in track_list:
    query_url_2 = f"https://api.spotify.com/v1/audio-features/{track}"
    _request = requests.get(query_url_2, headers=headers)
    _response = request.json()
    break

f = flatten_json(_response)
data = pd.DataFrame(json_normalize(f))
# make rows into columns so it's easier to read
data = data.transpose()
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
   print(data)
# First element is general information, second is countries themselves
val = countries_response[1][26]['name']
#print(val)
    
# print(json.dumps(_response, indent=4, sort_keys=True))
# Out:
#                                                                                                     0
# collaborative                                                                                   False
# description
# external_urls_spotify                               https://open.spotify.com/playlist/4hOKQuZbraPD...
# followers_href                                                                                   None
# followers_total                                                                                 18698
# href                                                https://api.spotify.com/v1/playlists/4hOKQuZbr...
# id                                                                             4hOKQuZbraPDIfaGbM3lKI
# images_0_height                                                                                   300
# images_0_url                                        https://i.scdn.co/image/d5905c3899a14a48bd67d4...
# ...

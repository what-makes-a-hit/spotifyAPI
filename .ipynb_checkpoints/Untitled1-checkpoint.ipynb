# %%
# %matplotlib inline

import pandas as pd
import random
import json
import time
import requests

from matplotlib import pyplot as plt

# %%
def load_list(from_list, to_list):
    
    for item in from_list:
        to_list.append(list(item))
    
def averages_summary(raw_data, agg_type):

    avg_danceability = df_clean["danceability"].agg(agg_type)
    avg_energy = df_clean["energy"].agg(agg_type)
    avg_key = df_clean["key"].agg(agg_type)
    avg_loudness = df_clean["loudness"].agg(agg_type)
    avg_mode = df_clean["mode"].agg(agg_type)
    avg_speechiness = df_clean["speechiness"].agg(agg_type)
    avg_acousticness = df_clean["acousticness"].agg(agg_type)
    avg_instrumentalness = df_clean["instrumentalness"].agg(agg_type)
    avg_liveness = df_clean["liveness"].agg(agg_type)
    avg_tempo = df_clean["tempo"].agg(agg_type)
    avg_valence = df_clean["valence"].agg(agg_type)
    avg_duration_ms = df_clean["duration_ms"].agg(agg_type)
    avg_time_signature = df_clean["time_signature"].agg(agg_type)

    summary_df = pd.DataFrame( [{'danceability': avg_danceability, 
                              'energy': avg_energy,
                              'key': avg_key,
                              'loudness': avg_loudness,
                              'mode': avg_mode,
                              'speechiness': avg_speechiness,
                              'acousticness': avg_acousticness,
                              'instrumentalness': avg_instrumentalness,
                              'liveness': avg_liveness,
                              'tempo': avg_tempo,
                              'valence': avg_valence,
                              'duration_ms': avg_duration_ms,
                              'time_signature': avg_time_signature}])

    return summary_df

# %%
from randomSongObjects import oneHundredRandom
from randomSongObjects import getRandomSpotifySong
from randomSongObjects import tenRandomfix
from randomSongObjects import tenRandomTwofix
from randomSongObjects import tenRandomThreefix
from randomSongObjects import tenRandomFourfix
from randomSongObjects import fortyRandomfix
from randomSongObjects import fortyRandomTwo

#choose one randomly
randomTop100 = random.sample(oneHundredRandom, k=25)
randomSpotify = random.sample(getRandomSpotifySong, k=25)
tenRandom = random.sample(tenRandomfix, k=4)
tenRandomTwo = random.sample(tenRandomTwofix, k=4)
tenRandomThree = random.sample(tenRandomThreefix, k=4)
tenRandomFour = random.sample(tenRandomFourfix, k=4)
fortyRandom = random.sample(fortyRandomfix, k=10)
fortyRandomTwo = random.sample(fortyRandomTwo, k=10)

random_list = []
# random_list.append(['track_name', 'track_id'])
load_list(randomTop100, random_list)
load_list(randomSpotify, random_list)
load_list(tenRandomfix, random_list)
load_list(tenRandomTwofix, random_list)
load_list(tenRandomThreefix, random_list)
load_list(tenRandomFourfix, random_list)
load_list(fortyRandomfix, random_list)
load_list(fortyRandomTwo, random_list)

print(random_list)
# Out:
# [{'3L0IKstjUgDFVQAbQIRZRv', 'R.I.P.'}, {'4tViDtaHuSLnh7HVJTrKhs', 'Power Over Me'}, {'6BtmXhTJMM9sBTHeYYASGz', "It's Time"}, {'Brace Face', '5N3jIzZRPB89dE6n6JeSd8'}, {"I'm N Luv (Wit a Stripper) (feat. Mike Jones)", '1lih9AUGlOI2qbAkptdBsr'}, {'On The Road (feat. Meek Mill & Lil Baby)', '12Fkyg9lpmaz2zmKOfw2Y2'}, {'She Gon Go', '7FknBUKLWwjWszRK1N0jqe'}, {'Raised A Fool (feat. Jay Rock, Ab-Soul & Zacari)', '5vtGYY6ZWl5n3izcVJ7n49'}, {'A Rosa E O Beija Flor - Live', '0kQKcJHzmv4P9EeRQFFV41'}, {'9 to 5', '4w3tQBXhn5345eUXDGBWZG'}]
for x in range(len(random_list_df)-1):
# for x in range(6):
        
    #-- query spotify API to retreive further track details
    track_name = random_list_df.iloc[x,0]
    track_id = random_list_df.iloc[x,1]
    
    if track_name is not None and track_id is not None:
        print(f"{track_name}: {track_id}")
        
        try:

            # read popularity
            _popularity_url = f"https://api.spotify.com/v1/tracks/{track_id}"
            _popularity_response = requests.get(_popularity_url, headers=headers)
            _j_popularity_response = _popularity_response.json()
            popularity = _j_popularity_response["popularity"]
#             print(_popularity_url)
            print(popularity)
#             print(json.dumps(_j_popularity_response, indent=4, sort_keys=True))
        except:
            print(f"{track_name} and {track_id} not found")

        _data_response_url = "https://api.spotify.com/v1/audio-features/" + track_id
        _data_response = requests.get(_data_response_url, headers=headers)
        _j_data_response = _data_response.json()
        print(json.dumps(_j_data_response, indent=4, sort_keys=True))

#         #-- compile the results for track details 
        try:
            result = {"track_name" : track_name, "track_id": track_id, "popularity": popularity,
                      "danceability": _j_data_response["danceability"], 
                      "energy": _j_data_response["energy"], 
                      "key": _j_data_response["key"], 
                      "loudness": _j_data_response["loudness"], 
                      "mode": _j_data_response["mode"], 
                      "speechiness": _j_data_response["speechiness"], 
                      "acousticness": _j_data_response["acousticness"], 
                      "instrumentalness": _j_data_response["instrumentalness"], 
                      "liveness": _j_data_response["liveness"],
                      "valence": _j_data_response["valence"], 
                      "tempo": _j_data_response["tempo"], 
                      "duration_ms": _j_data_response["duration_ms"], 
                      "time_signature": _j_data_response["time_signature"]
                         }

            control_sample_list.append(result)
        except:
            print(f"track {track_name} not loaded")

print(control_sample_list)
# Out:
# 3L0IKstjUgDFVQAbQIRZRv: R.I.P.
# 3L0IKstjUgDFVQAbQIRZRv and R.I.P. not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 3L0IKstjUgDFVQAbQIRZRv not loaded
# 4tViDtaHuSLnh7HVJTrKhs: Power Over Me
# 4tViDtaHuSLnh7HVJTrKhs and Power Over Me not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 4tViDtaHuSLnh7HVJTrKhs not loaded
# 6BtmXhTJMM9sBTHeYYASGz: It's Time
# 6BtmXhTJMM9sBTHeYYASGz and It's Time not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 6BtmXhTJMM9sBTHeYYASGz not loaded
# Brace Face: 5N3jIzZRPB89dE6n6JeSd8
# 63
# {
#     "acousticness": 0.251,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5N3jIzZRPB89dE6n6JeSd8",
#     "danceability": 0.58,
#     "duration_ms": 161933,
#     "energy": 0.711,
#     "id": "5N3jIzZRPB89dE6n6JeSd8",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.0383,
#     "loudness": -4.722,
#     "mode": 1,
#     "speechiness": 0.0441,
#     "tempo": 85.943,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5N3jIzZRPB89dE6n6JeSd8",
#     "type": "audio_features",
#     "uri": "spotify:track:5N3jIzZRPB89dE6n6JeSd8",
#     "valence": 0.604
# }
# I'm N Luv (Wit a Stripper) (feat. Mike Jones): 1lih9AUGlOI2qbAkptdBsr
# 67
# {
#     "acousticness": 0.00544,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1lih9AUGlOI2qbAkptdBsr",
#     "danceability": 0.731,
#     "duration_ms": 265333,
#     "energy": 0.368,
#     "id": "1lih9AUGlOI2qbAkptdBsr",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.193,
#     "loudness": -10.38,
#     "mode": 1,
#     "speechiness": 0.0688,
#     "tempo": 145.171,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1lih9AUGlOI2qbAkptdBsr",
#     "type": "audio_features",
#     "uri": "spotify:track:1lih9AUGlOI2qbAkptdBsr",
#     "valence": 0.512
# }
# On The Road (feat. Meek Mill & Lil Baby): 12Fkyg9lpmaz2zmKOfw2Y2
# 78
# {
#     "acousticness": 0.0589,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/12Fkyg9lpmaz2zmKOfw2Y2",
#     "danceability": 0.442,
#     "duration_ms": 218320,
#     "energy": 0.737,
#     "id": "12Fkyg9lpmaz2zmKOfw2Y2",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.102,
#     "loudness": -5.046,
#     "mode": 1,
#     "speechiness": 0.109,
#     "tempo": 112.93,
#     "time_signature": 5,
#     "track_href": "https://api.spotify.com/v1/tracks/12Fkyg9lpmaz2zmKOfw2Y2",
#     "type": "audio_features",
#     "uri": "spotify:track:12Fkyg9lpmaz2zmKOfw2Y2",
#     "valence": 0.21
# }
# She Gon Go: 7FknBUKLWwjWszRK1N0jqe
# 74
# {
#     "acousticness": 0.00195,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7FknBUKLWwjWszRK1N0jqe",
#     "danceability": 0.766,
#     "duration_ms": 121010,
#     "energy": 0.498,
#     "id": "7FknBUKLWwjWszRK1N0jqe",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.306,
#     "loudness": -10.147,
#     "mode": 0,
#     "speechiness": 0.0519,
#     "tempo": 104.006,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7FknBUKLWwjWszRK1N0jqe",
#     "type": "audio_features",
#     "uri": "spotify:track:7FknBUKLWwjWszRK1N0jqe",
#     "valence": 0.496
# }
# Raised A Fool (feat. Jay Rock, Ab-Soul & Zacari): 5vtGYY6ZWl5n3izcVJ7n49
# 44
# {
#     "acousticness": 0.151,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5vtGYY6ZWl5n3izcVJ7n49",
#     "danceability": 0.685,
#     "duration_ms": 338184,
#     "energy": 0.837,
#     "id": "5vtGYY6ZWl5n3izcVJ7n49",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.289,
#     "loudness": -7.811,
#     "mode": 0,
#     "speechiness": 0.258,
#     "tempo": 88.0,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5vtGYY6ZWl5n3izcVJ7n49",
#     "type": "audio_features",
#     "uri": "spotify:track:5vtGYY6ZWl5n3izcVJ7n49",
#     "valence": 0.711
# }
# A Rosa E O Beija Flor - Live: 0kQKcJHzmv4P9EeRQFFV41
# 7
# {
#     "acousticness": 0.606,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0kQKcJHzmv4P9EeRQFFV41",
#     "danceability": 0.499,
#     "duration_ms": 168093,
#     "energy": 0.91,
#     "id": "0kQKcJHzmv4P9EeRQFFV41",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.704,
#     "loudness": -2.873,
#     "mode": 1,
#     "speechiness": 0.106,
#     "tempo": 165.744,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0kQKcJHzmv4P9EeRQFFV41",
#     "type": "audio_features",
#     "uri": "spotify:track:0kQKcJHzmv4P9EeRQFFV41",
#     "valence": 0.547
# }
# 9 to 5: 4w3tQBXhn5345eUXDGBWZG
# 75
# {
#     "acousticness": 0.416,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4w3tQBXhn5345eUXDGBWZG",
#     "danceability": 0.554,
#     "duration_ms": 162467,
#     "energy": 0.783,
#     "id": "4w3tQBXhn5345eUXDGBWZG",
#     "instrumentalness": 1.54e-06,
#     "key": 6,
#     "liveness": 0.631,
#     "loudness": -5.852,
#     "mode": 1,
#     "speechiness": 0.0457,
#     "tempo": 105.39,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4w3tQBXhn5345eUXDGBWZG",
#     "type": "audio_features",
#     "uri": "spotify:track:4w3tQBXhn5345eUXDGBWZG",
#     "valence": 0.813
# }
# Can We Talk: 6a5jHgwqYMk9wlYJYfs3c9
# 65
# {
#     "acousticness": 0.0759,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6a5jHgwqYMk9wlYJYfs3c9",
#     "danceability": 0.658,
#     "duration_ms": 284587,
#     "energy": 0.711,
#     "id": "6a5jHgwqYMk9wlYJYfs3c9",
#     "instrumentalness": 1.77e-05,
#     "key": 2,
#     "liveness": 0.0446,
#     "loudness": -7.424,
#     "mode": 0,
#     "speechiness": 0.0425,
#     "tempo": 172.365,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6a5jHgwqYMk9wlYJYfs3c9",
#     "type": "audio_features",
#     "uri": "spotify:track:6a5jHgwqYMk9wlYJYfs3c9",
#     "valence": 0.614
# }
# All Your Love: 7G7zCzvyqz39BFE7TqPM3O
# 63
# {
#     "acousticness": 0.293,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7G7zCzvyqz39BFE7TqPM3O",
#     "danceability": 0.568,
#     "duration_ms": 175241,
#     "energy": 0.587,
#     "id": "7G7zCzvyqz39BFE7TqPM3O",
#     "instrumentalness": 0.329,
#     "key": 11,
#     "liveness": 0.137,
#     "loudness": -8.814,
#     "mode": 0,
#     "speechiness": 0.127,
#     "tempo": 174.682,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7G7zCzvyqz39BFE7TqPM3O",
#     "type": "audio_features",
#     "uri": "spotify:track:7G7zCzvyqz39BFE7TqPM3O",
#     "valence": 0.491
# }
# Everyday Peace: 7CGtdNBijQGEvkZeLU4699
# 61
# {
#     "acousticness": 0.925,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7CGtdNBijQGEvkZeLU4699",
#     "danceability": 0.194,
#     "duration_ms": 135325,
#     "energy": 0.0795,
#     "id": "7CGtdNBijQGEvkZeLU4699",
#     "instrumentalness": 0.898,
#     "key": 2,
#     "liveness": 0.104,
#     "loudness": -21.832,
#     "mode": 1,
#     "speechiness": 0.04,
#     "tempo": 76.547,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/7CGtdNBijQGEvkZeLU4699",
#     "type": "audio_features",
#     "uri": "spotify:track:7CGtdNBijQGEvkZeLU4699",
#     "valence": 0.0378
# }
# Promise (feat. Fetty Wap): 5IZc3KIVFhjzJ0L2kiXzUl
# 65
# {
#     "acousticness": 0.0599,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5IZc3KIVFhjzJ0L2kiXzUl",
#     "danceability": 0.797,
#     "duration_ms": 224240,
#     "energy": 0.469,
#     "id": "5IZc3KIVFhjzJ0L2kiXzUl",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.0753,
#     "loudness": -8.112,
#     "mode": 1,
#     "speechiness": 0.0646,
#     "tempo": 103.057,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5IZc3KIVFhjzJ0L2kiXzUl",
#     "type": "audio_features",
#     "uri": "spotify:track:5IZc3KIVFhjzJ0L2kiXzUl",
#     "valence": 0.481
# }
# You Need To Calm Down: 6RRNNciQGZEXnqk8SQ9yv5
# 84
# {
#     "acousticness": 0.00929,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6RRNNciQGZEXnqk8SQ9yv5",
#     "danceability": 0.771,
#     "duration_ms": 171360,
#     "energy": 0.671,
#     "id": "6RRNNciQGZEXnqk8SQ9yv5",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.0637,
#     "loudness": -5.617,
#     "mode": 1,
#     "speechiness": 0.0553,
#     "tempo": 85.026,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6RRNNciQGZEXnqk8SQ9yv5",
#     "type": "audio_features",
#     "uri": "spotify:track:6RRNNciQGZEXnqk8SQ9yv5",
#     "valence": 0.714
# }
# 7gijaEm7mLTkzoGTOftkK8: Adictiva
# 7gijaEm7mLTkzoGTOftkK8 and Adictiva not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 7gijaEm7mLTkzoGTOftkK8 not loaded
# Magic Hour: 2siIhRYyrbKp9rGFAD4TVx
# 66
# {
#     "acousticness": 0.799,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2siIhRYyrbKp9rGFAD4TVx",
#     "danceability": 0.522,
#     "duration_ms": 196320,
#     "energy": 0.278,
#     "id": "2siIhRYyrbKp9rGFAD4TVx",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.132,
#     "loudness": -11.512,
#     "mode": 1,
#     "speechiness": 0.0354,
#     "tempo": 76.038,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/2siIhRYyrbKp9rGFAD4TVx",
#     "type": "audio_features",
#     "uri": "spotify:track:2siIhRYyrbKp9rGFAD4TVx",
#     "valence": 0.194
# }
# 4TNFLwe6DhtR3Wn1JKMqMJ: Makeba
# 4TNFLwe6DhtR3Wn1JKMqMJ and Makeba not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 4TNFLwe6DhtR3Wn1JKMqMJ not loaded
# 1539 N. Calvert: 6XyxCBp6x3jvtxXvMN5sAA
# 63
# {
#     "acousticness": 0.278,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6XyxCBp6x3jvtxXvMN5sAA",
#     "danceability": 0.863,
#     "duration_ms": 157259,
#     "energy": 0.717,
#     "id": "6XyxCBp6x3jvtxXvMN5sAA",
#     "instrumentalness": 0.0826,
#     "key": 4,
#     "liveness": 0.0991,
#     "loudness": -3.143,
#     "mode": 0,
#     "speechiness": 0.17,
#     "tempo": 152.05,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6XyxCBp6x3jvtxXvMN5sAA",
#     "type": "audio_features",
#     "uri": "spotify:track:6XyxCBp6x3jvtxXvMN5sAA",
#     "valence": 0.357
# }
# 4Q3N4Ct4zCuIHuZ65E3BD4: Tunnel Vision
# 4Q3N4Ct4zCuIHuZ65E3BD4 and Tunnel Vision not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 4Q3N4Ct4zCuIHuZ65E3BD4 not loaded
# In The Air Tonight - 2015 Remastered: 18AXbzPzBS8Y3AkgSxzJPb
# 75
# {
#     "acousticness": 0.551,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/18AXbzPzBS8Y3AkgSxzJPb",
#     "danceability": 0.446,
#     "duration_ms": 336453,
#     "energy": 0.239,
#     "id": "18AXbzPzBS8Y3AkgSxzJPb",
#     "instrumentalness": 4.1e-06,
#     "key": 0,
#     "liveness": 0.0697,
#     "loudness": -13.945,
#     "mode": 1,
#     "speechiness": 0.0316,
#     "tempo": 189.507,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/18AXbzPzBS8Y3AkgSxzJPb",
#     "type": "audio_features",
#     "uri": "spotify:track:18AXbzPzBS8Y3AkgSxzJPb",
#     "valence": 0.298
# }
# We Don't Believe What's on TV: 22OqansuvEMQu9W0EfiGTI
# 67
# {
#     "acousticness": 0.23,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/22OqansuvEMQu9W0EfiGTI",
#     "danceability": 0.547,
#     "duration_ms": 177200,
#     "energy": 0.936,
#     "id": "22OqansuvEMQu9W0EfiGTI",
#     "instrumentalness": 3.04e-06,
#     "key": 9,
#     "liveness": 0.172,
#     "loudness": -4.023,
#     "mode": 1,
#     "speechiness": 0.102,
#     "tempo": 120.003,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/22OqansuvEMQu9W0EfiGTI",
#     "type": "audio_features",
#     "uri": "spotify:track:22OqansuvEMQu9W0EfiGTI",
#     "valence": 0.642
# }
# 2dgFqylK6gyILa4HY65u0y: I'm Ready
# 2dgFqylK6gyILa4HY65u0y and I'm Ready not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 2dgFqylK6gyILa4HY65u0y not loaded
# 5ravc2aiNoYmu9m37diYXW: Start Wit Me (feat. Gunna)
# 5ravc2aiNoYmu9m37diYXW and Start Wit Me (feat. Gunna) not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 5ravc2aiNoYmu9m37diYXW not loaded
# 368hMk29q0OhJuRjWL44Fm: u U U U u U did i mfken stutter?
# 368hMk29q0OhJuRjWL44Fm and u U U U u U did i mfken stutter? not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 368hMk29q0OhJuRjWL44Fm not loaded
# Gounod & Bach / Transc. Garcia: Ave Maria, CG 89a (Transc. Garcia for Guitar): 2As8aPyh7Ra8gYBJMwXPti
# 7
# {
#     "acousticness": 0.985,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2As8aPyh7Ra8gYBJMwXPti",
#     "danceability": 0.175,
#     "duration_ms": 172760,
#     "energy": 0.0585,
#     "id": "2As8aPyh7Ra8gYBJMwXPti",
#     "instrumentalness": 0.0426,
#     "key": 5,
#     "liveness": 0.0904,
#     "loudness": -20.921,
#     "mode": 1,
#     "speechiness": 0.0435,
#     "tempo": 85.202,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/2As8aPyh7Ra8gYBJMwXPti",
#     "type": "audio_features",
#     "uri": "spotify:track:2As8aPyh7Ra8gYBJMwXPti",
#     "valence": 0.148
# }
# All We Got (feat. Kanye West & Chicago Children's Choir): 3ZLyt2ndLFBh148XRYjYYZ
# 63
# {
#     "acousticness": 0.308,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3ZLyt2ndLFBh148XRYjYYZ",
#     "danceability": 0.531,
#     "duration_ms": 203794,
#     "energy": 0.544,
#     "id": "3ZLyt2ndLFBh148XRYjYYZ",
#     "instrumentalness": 1.89e-06,
#     "key": 0,
#     "liveness": 0.0835,
#     "loudness": -8.615,
#     "mode": 0,
#     "speechiness": 0.462,
#     "tempo": 131.921,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3ZLyt2ndLFBh148XRYjYYZ",
#     "type": "audio_features",
#     "uri": "spotify:track:3ZLyt2ndLFBh148XRYjYYZ",
#     "valence": 0.398
# }
# Under Pressure: 1mSClObliRtgPVT399COQH
# 56
# {
#     "acousticness": 0.394,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1mSClObliRtgPVT399COQH",
#     "danceability": 0.659,
#     "duration_ms": 245507,
#     "energy": 0.545,
#     "id": "1mSClObliRtgPVT399COQH",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.0859,
#     "loudness": -12.768,
#     "mode": 1,
#     "speechiness": 0.0514,
#     "tempo": 113.458,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1mSClObliRtgPVT399COQH",
#     "type": "audio_features",
#     "uri": "spotify:track:1mSClObliRtgPVT399COQH",
#     "valence": 0.406
# }
# 7t5MUcFIIayP1M6TNhtWE0: Summer Time High Time
# 7t5MUcFIIayP1M6TNhtWE0 and Summer Time High Time not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 7t5MUcFIIayP1M6TNhtWE0 not loaded
# 告白氣球: 1ivCIgrYZyE0BvItL4Z8lk
# 64
# {
#     "acousticness": 0.192,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1ivCIgrYZyE0BvItL4Z8lk",
#     "danceability": 0.59,
#     "duration_ms": 215147,
#     "energy": 0.572,
#     "id": "1ivCIgrYZyE0BvItL4Z8lk",
#     "instrumentalness": 0,
#     "key": 11,
#     "liveness": 0.109,
#     "loudness": -7.658,
#     "mode": 1,
#     "speechiness": 0.0379,
#     "tempo": 179.989,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1ivCIgrYZyE0BvItL4Z8lk",
#     "type": "audio_features",
#     "uri": "spotify:track:1ivCIgrYZyE0BvItL4Z8lk",
#     "valence": 0.448
# }
# 79LAFAkR1ATb4iIQvZuCL0: Most People Are Good
# 79LAFAkR1ATb4iIQvZuCL0 and Most People Are Good not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 79LAFAkR1ATb4iIQvZuCL0 not loaded
# 0q0Vsy1SHdUSrR7TJGNAVn: molly
# 0q0Vsy1SHdUSrR7TJGNAVn and molly not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 0q0Vsy1SHdUSrR7TJGNAVn not loaded
# Como Tu Me Tocas: 7zeR2pRar0MtmUd5hiAkLo
# 2
# {
#     "acousticness": 0.0557,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7zeR2pRar0MtmUd5hiAkLo",
#     "danceability": 0.865,
#     "duration_ms": 232240,
#     "energy": 0.749,
#     "id": "7zeR2pRar0MtmUd5hiAkLo",
#     "instrumentalness": 0.00226,
#     "key": 2,
#     "liveness": 0.0661,
#     "loudness": -7.131,
#     "mode": 1,
#     "speechiness": 0.064,
#     "tempo": 102.016,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7zeR2pRar0MtmUd5hiAkLo",
#     "type": "audio_features",
#     "uri": "spotify:track:7zeR2pRar0MtmUd5hiAkLo",
#     "valence": 0.401
# }
# 4UyAtnwhaKv7EG1BdkBYRI: Ready To Let Go
# 4UyAtnwhaKv7EG1BdkBYRI and Ready To Let Go not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 4UyAtnwhaKv7EG1BdkBYRI not loaded
# So It Goes: 0EA2RhRHL4KWeNa7JfD1Yw
# 66
# {
#     "acousticness": 0.812,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0EA2RhRHL4KWeNa7JfD1Yw",
#     "danceability": 0.576,
#     "duration_ms": 312960,
#     "energy": 0.556,
#     "id": "0EA2RhRHL4KWeNa7JfD1Yw",
#     "instrumentalness": 0.125,
#     "key": 0,
#     "liveness": 0.0943,
#     "loudness": -6.474,
#     "mode": 1,
#     "speechiness": 0.231,
#     "tempo": 148.173,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0EA2RhRHL4KWeNa7JfD1Yw",
#     "type": "audio_features",
#     "uri": "spotify:track:0EA2RhRHL4KWeNa7JfD1Yw",
#     "valence": 0.294
# }
# 0gV5B7zmJkS1aaH9APokrH: Wow Freestyle (feat. Kendrick Lamar)
# 0gV5B7zmJkS1aaH9APokrH and Wow Freestyle (feat. Kendrick Lamar) not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 0gV5B7zmJkS1aaH9APokrH not loaded
# 6nxOW44RKSH3OBw6ZP8yuZ: YOU CAN'T HOLD MY HEART
# 6nxOW44RKSH3OBw6ZP8yuZ and YOU CAN'T HOLD MY HEART not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 6nxOW44RKSH3OBw6ZP8yuZ not loaded
# 7GhIk7Il098yCjg4BQjzvb: Never Gonna Give You Up
# 7GhIk7Il098yCjg4BQjzvb and Never Gonna Give You Up not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 7GhIk7Il098yCjg4BQjzvb not loaded
# What You Know: 3UjtIALeg72qmJiKPWBvM3
# 67
# {
#     "acousticness": 0.000715,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3UjtIALeg72qmJiKPWBvM3",
#     "danceability": 0.561,
#     "duration_ms": 191707,
#     "energy": 0.741,
#     "id": "3UjtIALeg72qmJiKPWBvM3",
#     "instrumentalness": 1.4e-05,
#     "key": 6,
#     "liveness": 0.0822,
#     "loudness": -4.239,
#     "mode": 0,
#     "speechiness": 0.0419,
#     "tempo": 139.001,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3UjtIALeg72qmJiKPWBvM3",
#     "type": "audio_features",
#     "uri": "spotify:track:3UjtIALeg72qmJiKPWBvM3",
#     "valence": 0.776
# }
# High Fashion (feat. Mustard): 07KXEDMj78x68D884wgVEm
# 90
# {
#     "acousticness": 0.269,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/07KXEDMj78x68D884wgVEm",
#     "danceability": 0.831,
#     "duration_ms": 220487,
#     "energy": 0.499,
#     "id": "07KXEDMj78x68D884wgVEm",
#     "instrumentalness": 0,
#     "key": 11,
#     "liveness": 0.3,
#     "loudness": -8.442,
#     "mode": 0,
#     "speechiness": 0.114,
#     "tempo": 97.956,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/07KXEDMj78x68D884wgVEm",
#     "type": "audio_features",
#     "uri": "spotify:track:07KXEDMj78x68D884wgVEm",
#     "valence": 0.511
# }
# 3fB96InfRUB2DCjbrfzKUt: Burberry Headband
# 3fB96InfRUB2DCjbrfzKUt and Burberry Headband not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 3fB96InfRUB2DCjbrfzKUt not loaded
# Loyal (feat. Lil Wayne & Tyga): 5BrTUo0xP1wKXLJWUaGFtk
# 73
# {
#     "acousticness": 0.0168,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5BrTUo0xP1wKXLJWUaGFtk",
#     "danceability": 0.841,
#     "duration_ms": 264947,
#     "energy": 0.522,
#     "id": "5BrTUo0xP1wKXLJWUaGFtk",
#     "instrumentalness": 1.37e-06,
#     "key": 10,
#     "liveness": 0.188,
#     "loudness": -5.963,
#     "mode": 0,
#     "speechiness": 0.049,
#     "tempo": 99.059,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5BrTUo0xP1wKXLJWUaGFtk",
#     "type": "audio_features",
#     "uri": "spotify:track:5BrTUo0xP1wKXLJWUaGFtk",
#     "valence": 0.616
# }
# 21zOFoqYc4u1A2vFk2zXf3: Suite In E Minor For Lute, BWV 996 - Arr. Segovia: 2. Allemande
# 21zOFoqYc4u1A2vFk2zXf3 and Suite In E Minor For Lute, BWV 996 - Arr. Segovia: 2. Allemande not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 21zOFoqYc4u1A2vFk2zXf3 not loaded
# Y Hubo Alguien: 3pe81l2C3Qo3UdBKh0jJio
# 5
# {
#     "acousticness": 0.649,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3pe81l2C3Qo3UdBKh0jJio",
#     "danceability": 0.52,
#     "duration_ms": 388480,
#     "energy": 0.879,
#     "id": "3pe81l2C3Qo3UdBKh0jJio",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.175,
#     "loudness": -3.976,
#     "mode": 0,
#     "speechiness": 0.11,
#     "tempo": 93.769,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3pe81l2C3Qo3UdBKh0jJio",
#     "type": "audio_features",
#     "uri": "spotify:track:3pe81l2C3Qo3UdBKh0jJio",
#     "valence": 0.663
# }
# Against All Odds (Take a Look at Me Now) - 2016 Remaster: 63CHa6rmamv9OsehkRD8oz
# 73
# {
#     "acousticness": 0.198,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/63CHa6rmamv9OsehkRD8oz",
#     "danceability": 0.58,
#     "duration_ms": 206360,
#     "energy": 0.498,
#     "id": "63CHa6rmamv9OsehkRD8oz",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.132,
#     "loudness": -6.901,
#     "mode": 1,
#     "speechiness": 0.0277,
#     "tempo": 116.271,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/63CHa6rmamv9OsehkRD8oz",
#     "type": "audio_features",
#     "uri": "spotify:track:63CHa6rmamv9OsehkRD8oz",
#     "valence": 0.111
# }
# 6ZthdsKjWtiCxnxbhs74vF: Drip or Drown
# 6ZthdsKjWtiCxnxbhs74vF and Drip or Drown not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 6ZthdsKjWtiCxnxbhs74vF not loaded
# Simon Says (feat. Juicy J): 4l2maonUDTMvGGT4bmkB3h
# 62
# {
#     "acousticness": 0.0102,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4l2maonUDTMvGGT4bmkB3h",
#     "danceability": 0.909,
#     "duration_ms": 200123,
#     "energy": 0.815,
#     "id": "4l2maonUDTMvGGT4bmkB3h",
#     "instrumentalness": 7.31e-05,
#     "key": 7,
#     "liveness": 0.225,
#     "loudness": -4.72,
#     "mode": 1,
#     "speechiness": 0.251,
#     "tempo": 91.979,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4l2maonUDTMvGGT4bmkB3h",
#     "type": "audio_features",
#     "uri": "spotify:track:4l2maonUDTMvGGT4bmkB3h",
#     "valence": 0.49
# }
# Partita No. 4 in D Major, BWV 828: VI. Menuet: 5FUhnfkme52cQxvKesU8Kp
# 1
# {
#     "acousticness": 0.501,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5FUhnfkme52cQxvKesU8Kp",
#     "danceability": 0.398,
#     "duration_ms": 85467,
#     "energy": 0.507,
#     "id": "5FUhnfkme52cQxvKesU8Kp",
#     "instrumentalness": 0.983,
#     "key": 1,
#     "liveness": 0.111,
#     "loudness": -11.5,
#     "mode": 1,
#     "speechiness": 0.0336,
#     "tempo": 124.713,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5FUhnfkme52cQxvKesU8Kp",
#     "type": "audio_features",
#     "uri": "spotify:track:5FUhnfkme52cQxvKesU8Kp",
#     "valence": 0.934
# }
# Hold On (with Georgia Ku): 5Cevkgj9FyNRFIwY3xSCn8
# 62
# {
#     "acousticness": 0.0463,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5Cevkgj9FyNRFIwY3xSCn8",
#     "danceability": 0.506,
#     "duration_ms": 235263,
#     "energy": 0.744,
#     "id": "5Cevkgj9FyNRFIwY3xSCn8",
#     "instrumentalness": 6.62e-06,
#     "key": 9,
#     "liveness": 0.52,
#     "loudness": -3.605,
#     "mode": 1,
#     "speechiness": 0.042,
#     "tempo": 76.056,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5Cevkgj9FyNRFIwY3xSCn8",
#     "type": "audio_features",
#     "uri": "spotify:track:5Cevkgj9FyNRFIwY3xSCn8",
#     "valence": 0.396
# }
# anxiety (with FRND): 7my1wrfnHqssb3mtHEPWrI
# 67
# {
#     "acousticness": 0.0291,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7my1wrfnHqssb3mtHEPWrI",
#     "danceability": 0.652,
#     "duration_ms": 191036,
#     "energy": 0.715,
#     "id": "7my1wrfnHqssb3mtHEPWrI",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.156,
#     "loudness": -5.919,
#     "mode": 1,
#     "speechiness": 0.0388,
#     "tempo": 97.981,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7my1wrfnHqssb3mtHEPWrI",
#     "type": "audio_features",
#     "uri": "spotify:track:7my1wrfnHqssb3mtHEPWrI",
#     "valence": 0.618
# }
# Alaska: 4HfLQJtVT1KiX1eVedDyTm
# 68
# {
#     "acousticness": 0.411,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4HfLQJtVT1KiX1eVedDyTm",
#     "danceability": 0.847,
#     "duration_ms": 188000,
#     "energy": 0.386,
#     "id": "4HfLQJtVT1KiX1eVedDyTm",
#     "instrumentalness": 0.00176,
#     "key": 9,
#     "liveness": 0.108,
#     "loudness": -10.668,
#     "mode": 0,
#     "speechiness": 0.0507,
#     "tempo": 104.001,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4HfLQJtVT1KiX1eVedDyTm",
#     "type": "audio_features",
#     "uri": "spotify:track:4HfLQJtVT1KiX1eVedDyTm",
#     "valence": 0.178
# }
# 4llK75pXNWZz6KAho2Gp16: She Will Be Loved - Radio Mix
# 4llK75pXNWZz6KAho2Gp16 and She Will Be Loved - Radio Mix not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 4llK75pXNWZz6KAho2Gp16 not loaded
# 2YpeDb67231RjR0MgVLzsG: Old Town Road - Remix
# 2YpeDb67231RjR0MgVLzsG and Old Town Road - Remix not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 2YpeDb67231RjR0MgVLzsG not loaded
# No Brainer (feat. Justin Bieber, Chance the Rapper & Quavo): 03nPEoQOYMuDe7KmGljpmd
# 66
# {
#     "acousticness": 0.073,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/03nPEoQOYMuDe7KmGljpmd",
#     "danceability": 0.527,
#     "duration_ms": 260000,
#     "energy": 0.761,
#     "id": "03nPEoQOYMuDe7KmGljpmd",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.0865,
#     "loudness": -4.708,
#     "mode": 1,
#     "speechiness": 0.341,
#     "tempo": 135.543,
#     "time_signature": 5,
#     "track_href": "https://api.spotify.com/v1/tracks/03nPEoQOYMuDe7KmGljpmd",
#     "type": "audio_features",
#     "uri": "spotify:track:03nPEoQOYMuDe7KmGljpmd",
#     "valence": 0.653
# }
# 5XfQTbialQHn9PhDb0p85H: Crazy Bitch
# 5XfQTbialQHn9PhDb0p85H and Crazy Bitch not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 5XfQTbialQHn9PhDb0p85H not loaded
# Sonata No. 1 in D Minor, BWV 1001: IV. Presto: 0wjtOfSwZkH7BydiaVFAo4
# 7
# {
#     "acousticness": 0.894,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0wjtOfSwZkH7BydiaVFAo4",
#     "danceability": 0.28,
#     "duration_ms": 241467,
#     "energy": 0.613,
#     "id": "0wjtOfSwZkH7BydiaVFAo4",
#     "instrumentalness": 0.773,
#     "key": 1,
#     "liveness": 0.125,
#     "loudness": -14.524,
#     "mode": 0,
#     "speechiness": 0.039,
#     "tempo": 108.055,
#     "time_signature": 1,
#     "track_href": "https://api.spotify.com/v1/tracks/0wjtOfSwZkH7BydiaVFAo4",
#     "type": "audio_features",
#     "uri": "spotify:track:0wjtOfSwZkH7BydiaVFAo4",
#     "valence": 0.963
# }
# Hoy Tengo Ganas De Ti: 5sjRWCUwmvtqY7ct4a1j4O
# 7
# {
#     "acousticness": 0.324,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5sjRWCUwmvtqY7ct4a1j4O",
#     "danceability": 0.403,
#     "duration_ms": 291107,
#     "energy": 0.461,
#     "id": "5sjRWCUwmvtqY7ct4a1j4O",
#     "instrumentalness": 0,
#     "key": 3,
#     "liveness": 0.0716,
#     "loudness": -6.389,
#     "mode": 0,
#     "speechiness": 0.0394,
#     "tempo": 124.058,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5sjRWCUwmvtqY7ct4a1j4O",
#     "type": "audio_features",
#     "uri": "spotify:track:5sjRWCUwmvtqY7ct4a1j4O",
#     "valence": 0.257
# }
# Welcome to the Black Parade: 5wQnmLuC1W7ATsArWACrgW
# 77
# {
#     "acousticness": 0.000289,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5wQnmLuC1W7ATsArWACrgW",
#     "danceability": 0.217,
#     "duration_ms": 311107,
#     "energy": 0.905,
#     "id": "5wQnmLuC1W7ATsArWACrgW",
#     "instrumentalness": 0.00011,
#     "key": 2,
#     "liveness": 0.222,
#     "loudness": -4.103,
#     "mode": 1,
#     "speechiness": 0.0752,
#     "tempo": 96.95,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5wQnmLuC1W7ATsArWACrgW",
#     "type": "audio_features",
#     "uri": "spotify:track:5wQnmLuC1W7ATsArWACrgW",
#     "valence": 0.236
# }
# 7LtqwGP2UIj0FHbOsqm6VG: Slow Down Love
# 7LtqwGP2UIj0FHbOsqm6VG and Slow Down Love not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 7LtqwGP2UIj0FHbOsqm6VG not loaded
# 6MO2bfLHKykUgCChFdw91H: Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown)
# 6MO2bfLHKykUgCChFdw91H and Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 6MO2bfLHKykUgCChFdw91H not loaded
# Whiskey Lullaby (feat. Alison Krauss): 4BXkf6yww23Vdju7E1fUrn
# 63
# {
#     "acousticness": 0.74,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4BXkf6yww23Vdju7E1fUrn",
#     "danceability": 0.587,
#     "duration_ms": 259453,
#     "energy": 0.35,
#     "id": "4BXkf6yww23Vdju7E1fUrn",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.156,
#     "loudness": -10.954,
#     "mode": 1,
#     "speechiness": 0.0318,
#     "tempo": 74.479,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4BXkf6yww23Vdju7E1fUrn",
#     "type": "audio_features",
#     "uri": "spotify:track:4BXkf6yww23Vdju7E1fUrn",
#     "valence": 0.17
# }
# Attention: 5cF0dROlMOK5uNZtivgu50
# 80
# {
#     "acousticness": 0.109,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5cF0dROlMOK5uNZtivgu50",
#     "danceability": 0.775,
#     "duration_ms": 208787,
#     "energy": 0.613,
#     "id": "5cF0dROlMOK5uNZtivgu50",
#     "instrumentalness": 2.33e-05,
#     "key": 3,
#     "liveness": 0.134,
#     "loudness": -4.586,
#     "mode": 0,
#     "speechiness": 0.0542,
#     "tempo": 100.066,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5cF0dROlMOK5uNZtivgu50",
#     "type": "audio_features",
#     "uri": "spotify:track:5cF0dROlMOK5uNZtivgu50",
#     "valence": 0.797
# }
# Bad Bad: 2OUY5NdALupSoIQN9ZBH1a
# 71
# {
#     "acousticness": 0.491,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2OUY5NdALupSoIQN9ZBH1a",
#     "danceability": 0.682,
#     "duration_ms": 138683,
#     "energy": 0.809,
#     "id": "2OUY5NdALupSoIQN9ZBH1a",
#     "instrumentalness": 0,
#     "key": 3,
#     "liveness": 0.217,
#     "loudness": -4.331,
#     "mode": 0,
#     "speechiness": 0.378,
#     "tempo": 180.088,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2OUY5NdALupSoIQN9ZBH1a",
#     "type": "audio_features",
#     "uri": "spotify:track:2OUY5NdALupSoIQN9ZBH1a",
#     "valence": 0.812
# }
# Jump Around: 3TZwjdclvWt7iPJUnMpgcs
# 73
# {
#     "acousticness": 0.0113,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3TZwjdclvWt7iPJUnMpgcs",
#     "danceability": 0.854,
#     "duration_ms": 214947,
#     "energy": 0.71,
#     "id": "3TZwjdclvWt7iPJUnMpgcs",
#     "instrumentalness": 8.72e-05,
#     "key": 4,
#     "liveness": 0.166,
#     "loudness": -6.32,
#     "mode": 0,
#     "speechiness": 0.0793,
#     "tempo": 106.894,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3TZwjdclvWt7iPJUnMpgcs",
#     "type": "audio_features",
#     "uri": "spotify:track:3TZwjdclvWt7iPJUnMpgcs",
#     "valence": 0.818
# }
# These Days: 6U4S5Fcy4sNgYnKPh6LLdh
# 69
# {
#     "acousticness": 0.413,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6U4S5Fcy4sNgYnKPh6LLdh",
#     "danceability": 0.463,
#     "duration_ms": 172755,
#     "energy": 0.778,
#     "id": "6U4S5Fcy4sNgYnKPh6LLdh",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.16,
#     "loudness": -3.013,
#     "mode": 1,
#     "speechiness": 0.0489,
#     "tempo": 175.888,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6U4S5Fcy4sNgYnKPh6LLdh",
#     "type": "audio_features",
#     "uri": "spotify:track:6U4S5Fcy4sNgYnKPh6LLdh",
#     "valence": 0.424
# }
# Only Girl (In The World): 6jAsmDJI8iPhGWtS27kZ67
# 66
# {
#     "acousticness": 0.102,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6jAsmDJI8iPhGWtS27kZ67",
#     "danceability": 0.786,
#     "duration_ms": 235520,
#     "energy": 0.716,
#     "id": "6jAsmDJI8iPhGWtS27kZ67",
#     "instrumentalness": 1.72e-05,
#     "key": 11,
#     "liveness": 0.0557,
#     "loudness": -4.253,
#     "mode": 0,
#     "speechiness": 0.0409,
#     "tempo": 125.921,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6jAsmDJI8iPhGWtS27kZ67",
#     "type": "audio_features",
#     "uri": "spotify:track:6jAsmDJI8iPhGWtS27kZ67",
#     "valence": 0.595
# }
# Back To Life: 7Lr4XaxGpkAwa37IVgg22k
# 69
# {
#     "acousticness": 0.191,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7Lr4XaxGpkAwa37IVgg22k",
#     "danceability": 0.467,
#     "duration_ms": 214219,
#     "energy": 0.701,
#     "id": "7Lr4XaxGpkAwa37IVgg22k",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.0769,
#     "loudness": -4.997,
#     "mode": 1,
#     "speechiness": 0.0302,
#     "tempo": 132.041,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/7Lr4XaxGpkAwa37IVgg22k",
#     "type": "audio_features",
#     "uri": "spotify:track:7Lr4XaxGpkAwa37IVgg22k",
#     "valence": 0.28
# }
# 29HQG5FmpUH5nWwHDF163B: Ain't Equal
# 29HQG5FmpUH5nWwHDF163B and Ain't Equal not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 29HQG5FmpUH5nWwHDF163B not loaded
# Snapback: 7I5fYc4qKJddht8Ozhqqdx
# 63
# {
#     "acousticness": 0.305,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7I5fYc4qKJddht8Ozhqqdx",
#     "danceability": 0.687,
#     "duration_ms": 206507,
#     "energy": 0.793,
#     "id": "7I5fYc4qKJddht8Ozhqqdx",
#     "instrumentalness": 3.23e-06,
#     "key": 5,
#     "liveness": 0.1,
#     "loudness": -3.577,
#     "mode": 1,
#     "speechiness": 0.0333,
#     "tempo": 100.991,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7I5fYc4qKJddht8Ozhqqdx",
#     "type": "audio_features",
#     "uri": "spotify:track:7I5fYc4qKJddht8Ozhqqdx",
#     "valence": 0.673
# }
# Good Thing (with Kehlani): 5aUSEPNd3m5xliFK4pn5mU
# 78
# {
#     "acousticness": 0.399,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5aUSEPNd3m5xliFK4pn5mU",
#     "danceability": 0.693,
#     "duration_ms": 210901,
#     "energy": 0.564,
#     "id": "5aUSEPNd3m5xliFK4pn5mU",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.0409,
#     "loudness": -3.857,
#     "mode": 0,
#     "speechiness": 0.0378,
#     "tempo": 185.913,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/5aUSEPNd3m5xliFK4pn5mU",
#     "type": "audio_features",
#     "uri": "spotify:track:5aUSEPNd3m5xliFK4pn5mU",
#     "valence": 0.574
# }
# 63T7DJ1AFDD6Bn8VzG6JE8: Paint It, Black
# 63T7DJ1AFDD6Bn8VzG6JE8 and Paint It, Black not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 63T7DJ1AFDD6Bn8VzG6JE8 not loaded
# 6Ozh9Ok6h4Oi1wUSLtBseN: BOP
# 6Ozh9Ok6h4Oi1wUSLtBseN and BOP not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 6Ozh9Ok6h4Oi1wUSLtBseN not loaded
# When the Night is Over: 4FE9SgxcOoCNuGnaaU8TXz
# 62
# {
#     "acousticness": 0.0994,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4FE9SgxcOoCNuGnaaU8TXz",
#     "danceability": 0.681,
#     "duration_ms": 311227,
#     "energy": 0.419,
#     "id": "4FE9SgxcOoCNuGnaaU8TXz",
#     "instrumentalness": 0.15,
#     "key": 6,
#     "liveness": 0.123,
#     "loudness": -6.156,
#     "mode": 0,
#     "speechiness": 0.0258,
#     "tempo": 95.981,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/4FE9SgxcOoCNuGnaaU8TXz",
#     "type": "audio_features",
#     "uri": "spotify:track:4FE9SgxcOoCNuGnaaU8TXz",
#     "valence": 0.59
# }
# 7ESSLk9juK8vupg5A1LQq0: Piano Sonata No. 13 in E-Flat Major, Op. 27 No. 1 "Quasi una fantasia": I. Andante
# 7ESSLk9juK8vupg5A1LQq0 and Piano Sonata No. 13 in E-Flat Major, Op. 27 No. 1 "Quasi una fantasia": I. Andante not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 7ESSLk9juK8vupg5A1LQq0 not loaded
# 1ZYQWPWnQvr11DLF3Vj102: Que Bendición
# 1ZYQWPWnQvr11DLF3Vj102 and Que Bendición not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 1ZYQWPWnQvr11DLF3Vj102 not loaded
# 5Kjz86OFAoN6D4kF1BTSEc: Moon & Stars (feat. Maggie Lindemann)
# 5Kjz86OFAoN6D4kF1BTSEc and Moon & Stars (feat. Maggie Lindemann) not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 5Kjz86OFAoN6D4kF1BTSEc not loaded
# Daddy Issues: 5E30LdtzQTGqRvNd7l6kG5
# 75
# {
#     "acousticness": 0.0678,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5E30LdtzQTGqRvNd7l6kG5",
#     "danceability": 0.588,
#     "duration_ms": 260173,
#     "energy": 0.521,
#     "id": "5E30LdtzQTGqRvNd7l6kG5",
#     "instrumentalness": 0.149,
#     "key": 10,
#     "liveness": 0.123,
#     "loudness": -9.461,
#     "mode": 1,
#     "speechiness": 0.0329,
#     "tempo": 85.012,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5E30LdtzQTGqRvNd7l6kG5",
#     "type": "audio_features",
#     "uri": "spotify:track:5E30LdtzQTGqRvNd7l6kG5",
#     "valence": 0.337
# }
# 1QMpWmdDksbUNTdZlWo1wH: Orchestral Suite No. 3 in D Major, BWV 1068: II. Air
# 1QMpWmdDksbUNTdZlWo1wH and Orchestral Suite No. 3 in D Major, BWV 1068: II. Air not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 1QMpWmdDksbUNTdZlWo1wH not loaded
# Partita No. 2 in C Minor, BWV 826: I. Sinfonia: 0JCBepDnwU7phYKPYFefUj
# 2
# {
#     "acousticness": 0.811,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0JCBepDnwU7phYKPYFefUj",
#     "danceability": 0.299,
#     "duration_ms": 289440,
#     "energy": 0.445,
#     "id": "0JCBepDnwU7phYKPYFefUj",
#     "instrumentalness": 0.0295,
#     "key": 11,
#     "liveness": 0.232,
#     "loudness": -15.761,
#     "mode": 0,
#     "speechiness": 0.0398,
#     "tempo": 110.823,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/0JCBepDnwU7phYKPYFefUj",
#     "type": "audio_features",
#     "uri": "spotify:track:0JCBepDnwU7phYKPYFefUj",
#     "valence": 0.608
# }
# 2T5Ch09nefwckOu5NQvjIk: Carolina in My Mind
# 2T5Ch09nefwckOu5NQvjIk and Carolina in My Mind not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 2T5Ch09nefwckOu5NQvjIk not loaded
# Beautiful Escape: 5MChi9fdCbTIWDJPPUuuW6
# 64
# {
#     "acousticness": 0.0684,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5MChi9fdCbTIWDJPPUuuW6",
#     "danceability": 0.944,
#     "duration_ms": 276785,
#     "energy": 0.514,
#     "id": "5MChi9fdCbTIWDJPPUuuW6",
#     "instrumentalness": 0.00209,
#     "key": 5,
#     "liveness": 0.103,
#     "loudness": -7.895,
#     "mode": 1,
#     "speechiness": 0.195,
#     "tempo": 120.004,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5MChi9fdCbTIWDJPPUuuW6",
#     "type": "audio_features",
#     "uri": "spotify:track:5MChi9fdCbTIWDJPPUuuW6",
#     "valence": 0.331
# }
# Sacrifices (with EARTHGANG & J. Cole feat. Smino & Saba): 7wTA0NKIm6T7nP2kaymU2a
# 67
# {
#     "acousticness": 0.0858,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7wTA0NKIm6T7nP2kaymU2a",
#     "danceability": 0.825,
#     "duration_ms": 382307,
#     "energy": 0.672,
#     "id": "7wTA0NKIm6T7nP2kaymU2a",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.123,
#     "loudness": -7.108,
#     "mode": 1,
#     "speechiness": 0.418,
#     "tempo": 147.01,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7wTA0NKIm6T7nP2kaymU2a",
#     "type": "audio_features",
#     "uri": "spotify:track:7wTA0NKIm6T7nP2kaymU2a",
#     "valence": 0.246
# }
# 5hM5arv9KDbCHS0k9uqwjr: Borderline
# 5hM5arv9KDbCHS0k9uqwjr and Borderline not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 5hM5arv9KDbCHS0k9uqwjr not loaded
# 0EHR9OObFtjlhQB8wSt1m7: Mrs. Officer
# 0EHR9OObFtjlhQB8wSt1m7 and Mrs. Officer not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 0EHR9OObFtjlhQB8wSt1m7 not loaded
# Five Hours: 3haS1MDe2Zh8jJaeiiymSt
# 61
# {
#     "acousticness": 0.0197,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3haS1MDe2Zh8jJaeiiymSt",
#     "danceability": 0.88,
#     "duration_ms": 326888,
#     "energy": 0.821,
#     "id": "3haS1MDe2Zh8jJaeiiymSt",
#     "instrumentalness": 0.661,
#     "key": 5,
#     "liveness": 0.234,
#     "loudness": -2.545,
#     "mode": 0,
#     "speechiness": 0.118,
#     "tempo": 127.907,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3haS1MDe2Zh8jJaeiiymSt",
#     "type": "audio_features",
#     "uri": "spotify:track:3haS1MDe2Zh8jJaeiiymSt",
#     "valence": 0.575
# }
# 1Ci4wASMY4xtKVMeHA6Sd5: through the late night
# 1Ci4wASMY4xtKVMeHA6Sd5 and through the late night not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 1Ci4wASMY4xtKVMeHA6Sd5 not loaded
# Don't Start Now: 6WrI0LAC5M1Rw2MnX2ZvEg
# 97
# {
#     "acousticness": 0.0125,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6WrI0LAC5M1Rw2MnX2ZvEg",
#     "danceability": 0.794,
#     "duration_ms": 183290,
#     "energy": 0.793,
#     "id": "6WrI0LAC5M1Rw2MnX2ZvEg",
#     "instrumentalness": 0,
#     "key": 11,
#     "liveness": 0.0952,
#     "loudness": -4.521,
#     "mode": 0,
#     "speechiness": 0.0842,
#     "tempo": 123.941,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6WrI0LAC5M1Rw2MnX2ZvEg",
#     "type": "audio_features",
#     "uri": "spotify:track:6WrI0LAC5M1Rw2MnX2ZvEg",
#     "valence": 0.677
# }
# 5ImzbuXUwGS3nTUYbwUoHu: Partita No. 1 in B-Flat Major, BWV 825: I. Praeludium
# 5ImzbuXUwGS3nTUYbwUoHu and Partita No. 1 in B-Flat Major, BWV 825: I. Praeludium not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 5ImzbuXUwGS3nTUYbwUoHu not loaded
# 3mr13zNWprAzYYY0RinBCp: MERA (with Dalex & Álvaro Díaz)
# 3mr13zNWprAzYYY0RinBCp and MERA (with Dalex & Álvaro Díaz) not found
# {
#     "error": {
#         "message": "invalid request",
#         "status": 400
#     }
# }
# track 3mr13zNWprAzYYY0RinBCp not loaded
# [{'track_name': 'Brace Face', 'track_id': '5N3jIzZRPB89dE6n6JeSd8', 'popularity': 63, 'danceability': 0.58, 'energy': 0.711, 'key': 10, 'loudness': -4.722, 'mode': 1, 'speechiness': 0.0441, 'acousticness': 0.251, 'instrumentalness': 0, 'liveness': 0.0383, 'valence': 0.604, 'tempo': 85.943, 'duration_ms': 161933, 'time_signature': 4}, {'track_name': "I'm N Luv (Wit a Stripper) (feat. Mike Jones)", 'track_id': '1lih9AUGlOI2qbAkptdBsr', 'popularity': 67, 'danceability': 0.731, 'energy': 0.368, 'key': 8, 'loudness': -10.38, 'mode': 1, 'speechiness': 0.0688, 'acousticness': 0.00544, 'instrumentalness': 0, 'liveness': 0.193, 'valence': 0.512, 'tempo': 145.171, 'duration_ms': 265333, 'time_signature': 4}, {'track_name': 'On The Road (feat. Meek Mill & Lil Baby)', 'track_id': '12Fkyg9lpmaz2zmKOfw2Y2', 'popularity': 78, 'danceability': 0.442, 'energy': 0.737, 'key': 7, 'loudness': -5.046, 'mode': 1, 'speechiness': 0.109, 'acousticness': 0.0589, 'instrumentalness': 0, 'liveness': 0.102, 'valence': 0.21, 'tempo': 112.93, 'duration_ms': 218320, 'time_signature': 5}, {'track_name': 'She Gon Go', 'track_id': '7FknBUKLWwjWszRK1N0jqe', 'popularity': 74, 'danceability': 0.766, 'energy': 0.498, 'key': 7, 'loudness': -10.147, 'mode': 0, 'speechiness': 0.0519, 'acousticness': 0.00195, 'instrumentalness': 0, 'liveness': 0.306, 'valence': 0.496, 'tempo': 104.006, 'duration_ms': 121010, 'time_signature': 4}, {'track_name': 'Raised A Fool (feat. Jay Rock, Ab-Soul & Zacari)', 'track_id': '5vtGYY6ZWl5n3izcVJ7n49', 'popularity': 44, 'danceability': 0.685, 'energy': 0.837, 'key': 10, 'loudness': -7.811, 'mode': 0, 'speechiness': 0.258, 'acousticness': 0.151, 'instrumentalness': 0, 'liveness': 0.289, 'valence': 0.711, 'tempo': 88.0, 'duration_ms': 338184, 'time_signature': 4}, {'track_name': 'A Rosa E O Beija Flor - Live', 'track_id': '0kQKcJHzmv4P9EeRQFFV41', 'popularity': 7, 'danceability': 0.499, 'energy': 0.91, 'key': 8, 'loudness': -2.873, 'mode': 1, 'speechiness': 0.106, 'acousticness': 0.606, 'instrumentalness': 0, 'liveness': 0.704, 'valence': 0.547, 'tempo': 165.744, 'duration_ms': 168093, 'time_signature': 4}, {'track_name': '9 to 5', 'track_id': '4w3tQBXhn5345eUXDGBWZG', 'popularity': 75, 'danceability': 0.554, 'energy': 0.783, 'key': 6, 'loudness': -5.852, 'mode': 1, 'speechiness': 0.0457, 'acousticness': 0.416, 'instrumentalness': 1.54e-06, 'liveness': 0.631, 'valence': 0.813, 'tempo': 105.39, 'duration_ms': 162467, 'time_signature': 4}, {'track_name': 'Can We Talk', 'track_id': '6a5jHgwqYMk9wlYJYfs3c9', 'popularity': 65, 'danceability': 0.658, 'energy': 0.711, 'key': 2, 'loudness': -7.424, 'mode': 0, 'speechiness': 0.0425, 'acousticness': 0.0759, 'instrumentalness': 1.77e-05, 'liveness': 0.0446, 'valence': 0.614, 'tempo': 172.365, 'duration_ms': 284587, 'time_signature': 4}, {'track_name': 'All Your Love', 'track_id': '7G7zCzvyqz39BFE7TqPM3O', 'popularity': 63, 'danceability': 0.568, 'energy': 0.587, 'key': 11, 'loudness': -8.814, 'mode': 0, 'speechiness': 0.127, 'acousticness': 0.293, 'instrumentalness': 0.329, 'liveness': 0.137, 'valence': 0.491, 'tempo': 174.682, 'duration_ms': 175241, 'time_signature': 4}, {'track_name': 'Everyday Peace', 'track_id': '7CGtdNBijQGEvkZeLU4699', 'popularity': 61, 'danceability': 0.194, 'energy': 0.0795, 'key': 2, 'loudness': -21.832, 'mode': 1, 'speechiness': 0.04, 'acousticness': 0.925, 'instrumentalness': 0.898, 'liveness': 0.104, 'valence': 0.0378, 'tempo': 76.547, 'duration_ms': 135325, 'time_signature': 3}, {'track_name': 'Promise (feat. Fetty Wap)', 'track_id': '5IZc3KIVFhjzJ0L2kiXzUl', 'popularity': 65, 'danceability': 0.797, 'energy': 0.469, 'key': 8, 'loudness': -8.112, 'mode': 1, 'speechiness': 0.0646, 'acousticness': 0.0599, 'instrumentalness': 0, 'liveness': 0.0753, 'valence': 0.481, 'tempo': 103.057, 'duration_ms': 224240, 'time_signature': 4}, {'track_name': 'You Need To Calm Down', 'track_id': '6RRNNciQGZEXnqk8SQ9yv5', 'popularity': 84, 'danceability': 0.771, 'energy': 0.671, 'key': 2, 'loudn ...

# %%
control_sample_list_df = pd.DataFrame(control_sample_list)
print(control_sample_list_df.head())
# Out:
#                                          track_name                track_id  \
# 0                                        Brace Face  5N3jIzZRPB89dE6n6JeSd8
# 1     I'm N Luv (Wit a Stripper) (feat. Mike Jones)  1lih9AUGlOI2qbAkptdBsr
# 2          On The Road (feat. Meek Mill & Lil Baby)  12Fkyg9lpmaz2zmKOfw2Y2
# 3                                        She Gon Go  7FknBUKLWwjWszRK1N0jqe
# 4  Raised A Fool (feat. Jay Rock, Ab-Soul & Zacari)  5vtGYY6ZWl5n3izcVJ7n49
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          63         0.580   0.711   10    -4.722     1       0.0441
# 1          67         0.731   0.368    8   -10.380     1       0.0688
# 2          78         0.442   0.737    7    -5.046     1       0.1090
# 3          74         0.766   0.498    7   -10.147     0       0.0519
# 4          44         0.685   0.837   10    -7.811     0       0.2580
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 
# 22      0.000715          0.000014    0.0822   0.7760  139.001       191707
# 23      0.269000          0.000000    0.3000   0.5110   97.956       220487
# 24      0.016800          0.000001    0.1880   0.6160   99.059       264947
# 25      0.649000          0.000000    0.1750   0.6630   93.769       388480
# 26      0.198000          0.000000    0.1320   0.1110  116.271       206360
# 27      0.010200          0.000073    0.2250   0.4900   91.979       200123
# 28      0.501000          0.983000    0.1110   0.9340  124.713        85467
# 29      0.046300          0.000007    0.5200   0.3960   76.056       235263
# 30      0.029100          0.000000    0.1560   0.6180   97.981       191036
# 31      0.411000          0.001760    0.1080   0.1780  104.001       188000
# 32      0.073000          0.000000    0.0865   0.6530  135.543       260000
# 33      0.894000          0.773000    0.1250   0.9630  108.055       241467
# 34      0.324000          0.000000    0.0716   0.2570  124.058       291107
# 35      0.000289          0.000110    0.2220   0.2360   96.950       311107
# 36      0.740000          0.000000    0.1560   0.1700   74.479       259453
# 37      0.109000          0.000023    0.1340   0.7970  100.066       208787
# 38      0.491000          0.000000    0.2170   0.8120  180.088       138683
# 39      0.011300          0.000087    0.1660   0.8180  106.894       214947
# 40      0.413000          0.000000    0.1600   0.4240  175.888       172755
# 41      0.102000          0.000017    0.0557   0.5950  125.921       235520
# 42      0.191000          0.000000    0.0769   0.2800  132.041       214219
# 43      0.305000          0.000003    0.1000   0.6730  100.991       206507
# 44      0.399000          0.000000    0.0409   0.5740  185.913       210901
# 45      0.099400          0.150000    0.1230   0.5900   95.981       311227
# 46      0.067800          0.149000    0.1230   0.3370   85.012       260173
# 47      0.811000          0.029500    0.2320   0.6080  110.823       289440
# 48      0.068400          0.002090    0.1030   0.3310  120.004       276785
# 49      0.085800          0.000000    0.1230   0.2460  147.010       382307
# 50      0.019700          0.661000    0.2340   0.5750  127.907       326888
# 51      0.012500          0.000000    0.0952   0.6770  123.941       183290
#
#     time_signature
# 0                4
# 1                4
# 2                5
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                3
# 10               4
# 11               4
# 12               3
# 13               4
# 14               4
# 15               4
# 16               3
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               5
# 33               1
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               3
# 43               4
# 44               3
# 45               3
# 46               4
# 47               3
# 48               4
# 49               4
# 50               4
# 51               4

# %%
# Plot out energy versus loudness
loudness_values = df_clean['energy']
energy_values = df_clean['loudness']
plt.scatter(energy_values,loudness_values)
plt.xlabel('energy')
plt.ylabel('loudness')
plt.show()

# %%
summary_df = averages_summary(df_clean, 'mean')
print(summary_df)
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      0.617231  0.611942  5.326923 -7.496385  0.576923     0.098906
#
#    acousticness  instrumentalness  liveness       tempo   valence  \
# 0      0.284738           0.08133  0.160229  119.530173  0.494727
#
#      duration_ms  time_signature
# 0  227753.192308        3.846154

# %%
# %matplotlib inline

import pandas as pd
import random
import json
import time
import requests

from matplotlib import pyplot as plt

# %%
def load_list(from_list, to_list):
    for x in range(len(from_list) - 1):
#         print(from_list[x])
        for key, value in from_list[x].items():
            temp = [key,value]
            to_list.append(temp)
    
def averages_summary(raw_data, agg_type):

    avg_danceability = df_clean["danceability"].agg(agg_type)
    avg_energy = df_clean["energy"].agg(agg_type)
    avg_key = df_clean["key"].agg(agg_type)
    avg_loudness = df_clean["loudness"].agg(agg_type)
    avg_mode = df_clean["mode"].agg(agg_type)
    avg_speechiness = df_clean["speechiness"].agg(agg_type)
    avg_acousticness = df_clean["acousticness"].agg(agg_type)
    avg_instrumentalness = df_clean["instrumentalness"].agg(agg_type)
    avg_liveness = df_clean["liveness"].agg(agg_type)
    avg_tempo = df_clean["tempo"].agg(agg_type)
    avg_valence = df_clean["valence"].agg(agg_type)
    avg_duration_ms = df_clean["duration_ms"].agg(agg_type)
    avg_time_signature = df_clean["time_signature"].agg(agg_type)

    summary_df = pd.DataFrame( [{'danceability': avg_danceability, 
                              'energy': avg_energy,
                              'key': avg_key,
                              'loudness': avg_loudness,
                              'mode': avg_mode,
                              'speechiness': avg_speechiness,
                              'acousticness': avg_acousticness,
                              'instrumentalness': avg_instrumentalness,
                              'liveness': avg_liveness,
                              'tempo': avg_tempo,
                              'valence': avg_valence,
                              'duration_ms': avg_duration_ms,
                              'time_signature': avg_time_signature}])

    return summary_df

# %%
from randomSongObjects import oneHundredRandom
from randomSongObjects import getRandomSpotifySong
# from randomSongObjects import tenRandomfix
# from randomSongObjects import tenRandomTwofix
# from randomSongObjects import tenRandomThreefix
# from randomSongObjects import tenRandomFourfix
# from randomSongObjects import fortyRandomfix
# from randomSongObjects import fortyRandomTwo

#choose one randomly
randomTop100 = random.sample(oneHundredRandom, k=100)
randomSpotify = random.sample(getRandomSpotifySong, k=100)
# tenRandom = random.sample(tenRandomfix, k=5)
# tenRandomTwo = random.sample(tenRandomTwofix, k=5)
# tenRandomThree = random.sample(tenRandomThreefix, k=10)
# tenRandomFour = random.sample(tenRandomFourfix, k=10)
# fortyRandom = random.sample(fortyRandomfix, k=10)
# fortyRandomTwo = random.sample(fortyRandomTwo, k=10)

random_list = []
# random_list.append(['track_name', 'track_id'])
load_list(randomTop100, random_list)
load_list(randomSpotify, random_list)
# load_list(tenRandomfix, random_list)
# load_list(tenRandomTwofix, random_list)
# load_list(tenRandomThreefix, random_list)
# load_list(tenRandomFourfix, random_list)
# load_list(fortyRandomfix, random_list)
# load_list(fortyRandomTwo, random_list)

print(random_list)
# Out:
# [['Nobody', '2qfEcCkEo5NscA9GL7ER72'], ['Lost in the Middle of Nowhere (feat. Becky G)', '5KfKPfX5cZvOuHoy9io65A'], ["Look At Me Now (feat. Lil' Wayne & Busta Rhymes)", '3hsmbFKT5Cujb5GQjqEU39'], ['Futsal Shuffle 2020', '2Ec33AVlkTTq8BHFgBTdQs'], ['Heart Of Glass - Special Mix', '0a4agFmqHXxcZl1nho1BxM'], ['Sonata in C Major, BWW 966: I. Praeludium', '0U7oxeg9xWG8hyRWiKYriY'], ["If You're Gonna Lie", '0mPTZjG5PElXTUIxj1nqgp'], ['Sex on Fire', '0ntQJM78wzOLVeCUAW7Y45'], ['Unmeltable Me - Outtake', '09MvGKcju2jf2ktxDa0s17'], ['How U Feel', '7CWiWkccuRRdrmaW6AjVEf'], ['Kiss It Better', '0UHB9METy4VCXNgkcGqHqS'], ['Forever Young', '56bHclo7YNvpujMveLElQn'], ['Hair Up', '2986J0T5CGwJGY3aqgANtE'], ['Work It', '3jagJCUbdqhDSPuxP8cAqF'], ['In the Name of Love', '23L5CiUhw2jV1OIMwthR3S'], ['Forever ... (is a long time)', '6BORJ0ZazxMBpM3cWg79Id'], ['Broke Leg (with Quavo & Tyga)', '5CKtlUULFD5aPVX4PL02H6'], ["Uncle John's Band", '1pBPTKMykvrbCz5J5tPTsd'], ['Suite In E Minor For Lute, BWV 996 - Arr. Segovia: 2. Allemande', '21zOFoqYc4u1A2vFk2zXf3'], ['Ya Me Enteré', '4ggabbjjuHrG06SsYnqvEs'], ['Hillbilly', '2TlGQg8UKymxu3frqMXeO2'], ['Lay Me Down', '64GRDrL1efgXclrhVCeuA0'], ['Just Another Day In Paradise', '4LlNoNZflek4hZyZigCxpW'], ['Tokyo Drift (Fast & Furious) - From "The Fast And The Furious: Tokyo Drift" Soundtrack', '5iJfzXKvQXlYOBtEQhEmpA'], ['Who Needs Love', '2ktxr00GpTtbMNeBjNeY8D'], ['Ignorantes', '3wYRLYuO1M88d8woWUIxct'], ['UFOF', '1DXvEWgI1xoxmKv2Zd3pNE'], ['Clean & Pure White Noise', '18lKp9uRyR2xJZFvg8ZWUC'], ['Another In The Fire - Live', '5PmHmU5AaBy9ld3bdQkD96'], ['Shepherd of Fire', '1fQaoh3imrMunWVZh5kf90'], ['Waiting On the World to Change', '5imShWWzwqfAJ9gXFpGAQh'], ['Baby Pluto', '0MBbqhCETOfzONwgSAtKpI'], ['The Only Exception', '7JIuqL4ZqkpfGKQhYlrirs'], ['This Is Me', '45aBsnKRWUzhwbcqOJLwfe'], ['Slide', '0nnwn7LWHCAu09jfuH1xTA'], ['En Cero', '51uLQESb4VnYAbs5WtGxho'], ['Ni**as In Paris', '2KpCpk6HjXXLb7nnXoXA5O'], ['Suite: Judy Blue Eyes - Remastered', '2PuUFT13yCzUOZun94WOXv'], ['Demons', '4RtYR0ExTUZSpHIuoUJBDR'], ['Stay A Little Longer', '23EkfwUdsRIz7jAZIcC8gb'], ['Your Peace (feat. Lil Baby)', '6uNuT1YKpKjgZOOKiY4Nmf'], ['Estamos Bien', '2OWVCFTolecLiGZPquvWvT'], ['Where I Come From', '10ps1I1sIMRNZW11eceN7W'], ['No More Parties In LA', '0zLClc0emc6qUeV1p5nc99'], ['Dancing On My Own - Radio Edit', '7g13jf3zqlP5S68Voo5v9m'], ['Cannibal', '3JTMWdhcJPiegDSe7SvZS3'], ['Unlove You', '1OAVOMutu0LdzV8dEv7Rb9'], ['my boy', '1RGasjWLZ4qMN7wbtkLa3u'], ['Sultans of Swing', '5x5QjgqY5jRiiMcB1gkueB'], ['Weak', '71EHOyEOhNx1SzTebRRyng'], ['En Mis Dedos un Gallito', '0w05EANAQs2Cf3xj5daRPY'], ['Are You Gonna Be My Girl', '305WCRhhS10XUcH6AEwZk6'], ['Season Ticket Holder (feat. D. Wade, Raphael Saadiq & UD)', '7APQE45T3fsAPbfFuEtoQE'], ["Even Though I'm Leaving", '5aZQrb2TXWEh9uZR4HEY3r'], ["Knockin' On Heaven's Door", '4JiEyzf0Md7KEFFGWDDdCr'], ['High Cost Of Living', '73sWpECi7iZrcISLSRxuaH'], ['Estamos Arriba', '0bCPJsVGDxPYwQMDZMi4NW'], ['Solita', '7rwX0O3RlxqqIjQM8evm5E'], ['Turn Up the Music', '4bb2UdCvi9LynD4rWvE06T'], ['Heartbeat (BTS World Original Soundtrack)', '5EgYDyMDCi8X0zDydTF7Rb'], ['Last Resort', '5W8YXBz9MTIDyrpYaCg2Ky'], ['Ashley (with DaBaby)', '4gH4e5ENzVDg4N8fOp2vDP'], ['All Of The Lights', '22L7bfCiAkJo5xGSQgmiIO'], ['Up Up & Away', '1RUTIdTnFs8lHSc0Zr4UJB'], ['Candy Paint', '32lItqlMi4LBhb4k0BaSaC'], ['UN PESO', '7hynhxDoDpgMIV12JuVtNa'], ['10,000 Degrees', '4nutwPQrK56fFmrAMgyPhz'], ['UP THE SMOKE (with Offset)', '3faAAUxohrxqYhPlneZ3XV'], ['ME! (feat. Brendon Urie of Panic! At The Disco)', '2Rk4JlNc2TPmZe2af99d45'], ['Electric (feat. Khalid)', '2mj7x99sNUsVHPBRK51zlG'], ['La Modelo', '2SbzdGpOKlH3HIAGTWTbwU'], ['English Suite No. 1 in A Major, BWV 806: IX. Gigue', '78NvjLtG81xgPKFqgAl5oC'], ['Síguelo Bailando', '5Y9fnynLlIvqtM710MHzfz'], ['Quit (feat. Ariana Grande)', '4rwqrKdwlFWJ6LvPYaOtgn'], ["The Times They Are A-Changin'", '52vA3CYKZqZVdQnzRrdZt6'], ['Besos En Guerra', '7i8cN29xPG9h0ClT7I ...

# %%
control_sample_list = []
headers = {'Accept': 'application/json', 'Content-Type' : 'application/json','Authorization': 'Bearer BQAUJDK17t1XpoNl6Z31SOEGdrJgYxsuPqXCKdMFYb1fY4-8klSwuKyZZrrBPU1TIpdyA-KcxD7tSlc77iQGFFE2gxFOJ8kHhD-nk4qZ6bjKyXnYzb_ebmTh6BjZ-3l1WFS9RIZk2vYL4zQfBkxj4tIpG2j-DGxoE0EIEj4h0oShmC_ZdxTIdZgsVcBdDjJf1Vak13gY5cX4DZCdvul5EDp38Rgic9Krl2S2umtRGF3MOeCSR7MTDG7OsNIk0gNiGeo4qXsu'}

random_list_df = pd.DataFrame(random_list)
# print(random_list_df)

for x in range(len(random_list_df)-1):
# for x in range(6):
        
    #-- query spotify API to retreive further track details
    track_name = random_list_df.iloc[x,0]
    track_id = random_list_df.iloc[x,1]
    
    if track_name is not None and track_id is not None:
        print(f"{track_name}: {track_id}")
        
        try:

            # read popularity
            _popularity_url = f"https://api.spotify.com/v1/tracks/{track_id}"
            _popularity_response = requests.get(_popularity_url, headers=headers)
            _j_popularity_response = _popularity_response.json()
            popularity = _j_popularity_response["popularity"]
#             print(_popularity_url)
            print(popularity)
#             print(json.dumps(_j_popularity_response, indent=4, sort_keys=True))
        except:
            print(f"{track_name} and {track_id} not found")

        _data_response_url = "https://api.spotify.com/v1/audio-features/" + track_id
        _data_response = requests.get(_data_response_url, headers=headers)
        _j_data_response = _data_response.json()
        print(json.dumps(_j_data_response, indent=4, sort_keys=True))

#         #-- compile the results for track details 
        try:
            result = {"track_name" : track_name, "track_id": track_id, "popularity": popularity,
                      "danceability": _j_data_response["danceability"], 
                      "energy": _j_data_response["energy"], 
                      "key": _j_data_response["key"], 
                      "loudness": _j_data_response["loudness"], 
                      "mode": _j_data_response["mode"], 
                      "speechiness": _j_data_response["speechiness"], 
                      "acousticness": _j_data_response["acousticness"], 
                      "instrumentalness": _j_data_response["instrumentalness"], 
                      "liveness": _j_data_response["liveness"],
                      "valence": _j_data_response["valence"], 
                      "tempo": _j_data_response["tempo"], 
                      "duration_ms": _j_data_response["duration_ms"], 
                      "time_signature": _j_data_response["time_signature"]
                         }

            control_sample_list.append(result)
        except:
            print(f"track {track_name} not loaded")

print(control_sample_list)
# Out:
# Nobody: 2qfEcCkEo5NscA9GL7ER72
# 76
# {
#     "acousticness": 0.269,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2qfEcCkEo5NscA9GL7ER72",
#     "danceability": 0.673,
#     "duration_ms": 211040,
#     "energy": 0.687,
#     "id": "2qfEcCkEo5NscA9GL7ER72",
#     "instrumentalness": 0,
#     "key": 6,
#     "liveness": 0.181,
#     "loudness": -5.295,
#     "mode": 0,
#     "speechiness": 0.0623,
#     "tempo": 96.964,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2qfEcCkEo5NscA9GL7ER72",
#     "type": "audio_features",
#     "uri": "spotify:track:2qfEcCkEo5NscA9GL7ER72",
#     "valence": 0.524
# }
# Lost in the Middle of Nowhere (feat. Becky G): 5KfKPfX5cZvOuHoy9io65A
# 61
# {
#     "acousticness": 0.00184,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5KfKPfX5cZvOuHoy9io65A",
#     "danceability": 0.559,
#     "duration_ms": 188920,
#     "energy": 0.754,
#     "id": "5KfKPfX5cZvOuHoy9io65A",
#     "instrumentalness": 0.000462,
#     "key": 6,
#     "liveness": 0.0366,
#     "loudness": -5.344,
#     "mode": 0,
#     "speechiness": 0.0481,
#     "tempo": 85.993,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5KfKPfX5cZvOuHoy9io65A",
#     "type": "audio_features",
#     "uri": "spotify:track:5KfKPfX5cZvOuHoy9io65A",
#     "valence": 0.438
# }
# Look At Me Now (feat. Lil' Wayne & Busta Rhymes): 3hsmbFKT5Cujb5GQjqEU39
# 71
# {
#     "acousticness": 0.0339,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3hsmbFKT5Cujb5GQjqEU39",
#     "danceability": 0.767,
#     "duration_ms": 222587,
#     "energy": 0.677,
#     "id": "3hsmbFKT5Cujb5GQjqEU39",
#     "instrumentalness": 5.51e-06,
#     "key": 11,
#     "liveness": 0.144,
#     "loudness": -6.128,
#     "mode": 0,
#     "speechiness": 0.184,
#     "tempo": 146.155,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3hsmbFKT5Cujb5GQjqEU39",
#     "type": "audio_features",
#     "uri": "spotify:track:3hsmbFKT5Cujb5GQjqEU39",
#     "valence": 0.538
# }
# Futsal Shuffle 2020: 2Ec33AVlkTTq8BHFgBTdQs
# 85
# {
#     "acousticness": 0.0327,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2Ec33AVlkTTq8BHFgBTdQs",
#     "danceability": 0.881,
#     "duration_ms": 198913,
#     "energy": 0.457,
#     "id": "2Ec33AVlkTTq8BHFgBTdQs",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.231,
#     "loudness": -8.191,
#     "mode": 0,
#     "speechiness": 0.156,
#     "tempo": 136.97,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2Ec33AVlkTTq8BHFgBTdQs",
#     "type": "audio_features",
#     "uri": "spotify:track:2Ec33AVlkTTq8BHFgBTdQs",
#     "valence": 0.296
# }
# Heart Of Glass - Special Mix: 0a4agFmqHXxcZl1nho1BxM
# 69
# {
#     "acousticness": 0.015,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0a4agFmqHXxcZl1nho1BxM",
#     "danceability": 0.694,
#     "duration_ms": 275733,
#     "energy": 0.577,
#     "id": "0a4agFmqHXxcZl1nho1BxM",
#     "instrumentalness": 0.00836,
#     "key": 4,
#     "liveness": 0.0853,
#     "loudness": -14.63,
#     "mode": 1,
#     "speechiness": 0.0308,
#     "tempo": 114.478,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0a4agFmqHXxcZl1nho1BxM",
#     "type": "audio_features",
#     "uri": "spotify:track:0a4agFmqHXxcZl1nho1BxM",
#     "valence": 0.845
# }
# Sonata in C Major, BWW 966: I. Praeludium: 0U7oxeg9xWG8hyRWiKYriY
# 7
# {
#     "acousticness": 0.867,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0U7oxeg9xWG8hyRWiKYriY",
#     "danceability": 0.368,
#     "duration_ms": 105040,
#     "energy": 0.378,
#     "id": "0U7oxeg9xWG8hyRWiKYriY",
#     "instrumentalness": 0.859,
#     "key": 11,
#     "liveness": 0.078,
#     "loudness": -17.274,
#     "mode": 1,
#     "speechiness": 0.0383,
#     "tempo": 61.35,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/0U7oxeg9xWG8hyRWiKYriY",
#     "type": "audio_features",
#     "uri": "spotify:track:0U7oxeg9xWG8hyRWiKYriY",
#     "valence": 0.482
# }
# If You're Gonna Lie: 0mPTZjG5PElXTUIxj1nqgp
# 64
# {
#     "acousticness": 0.607,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0mPTZjG5PElXTUIxj1nqgp",
#     "danceability": 0.671,
#     "duration_ms": 203113,
#     "energy": 0.763,
#     "id": "0mPTZjG5PElXTUIxj1nqgp",
#     "instrumentalness": 2.16e-05,
#     "key": 8,
#     "liveness": 0.495,
#     "loudness": -5.877,
#     "mode": 1,
#     "speechiness": 0.305,
#     "tempo": 149.87,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0mPTZjG5PElXTUIxj1nqgp",
#     "type": "audio_features",
#     "uri": "spotify:track:0mPTZjG5PElXTUIxj1nqgp",
#     "valence": 0.469
# }
# Sex on Fire: 0ntQJM78wzOLVeCUAW7Y45
# 78
# {
#     "acousticness": 0.00172,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0ntQJM78wzOLVeCUAW7Y45",
#     "danceability": 0.542,
#     "duration_ms": 203347,
#     "energy": 0.905,
#     "id": "0ntQJM78wzOLVeCUAW7Y45",
#     "instrumentalness": 0.0104,
#     "key": 9,
#     "liveness": 0.136,
#     "loudness": -5.653,
#     "mode": 1,
#     "speechiness": 0.054,
#     "tempo": 153.398,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0ntQJM78wzOLVeCUAW7Y45",
#     "type": "audio_features",
#     "uri": "spotify:track:0ntQJM78wzOLVeCUAW7Y45",
#     "valence": 0.374
# }
# Unmeltable Me - Outtake: 09MvGKcju2jf2ktxDa0s17
# 59
# {
#     "acousticness": 0.402,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/09MvGKcju2jf2ktxDa0s17",
#     "danceability": 0.685,
#     "duration_ms": 85306,
#     "energy": 0.435,
#     "id": "09MvGKcju2jf2ktxDa0s17",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.312,
#     "loudness": -8.804,
#     "mode": 1,
#     "speechiness": 0.622,
#     "tempo": 79.168,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/09MvGKcju2jf2ktxDa0s17",
#     "type": "audio_features",
#     "uri": "spotify:track:09MvGKcju2jf2ktxDa0s17",
#     "valence": 0.765
# }
# How U Feel: 7CWiWkccuRRdrmaW6AjVEf
# 57
# {
#     "acousticness": 0.0532,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7CWiWkccuRRdrmaW6AjVEf",
#     "danceability": 0.86,
#     "duration_ms": 205682,
#     "energy": 0.799,
#     "id": "7CWiWkccuRRdrmaW6AjVEf",
#     "instrumentalness": 2.54e-05,
#     "key": 2,
#     "liveness": 0.369,
#     "loudness": -2.446,
#     "mode": 1,
#     "speechiness": 0.149,
#     "tempo": 140.005,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7CWiWkccuRRdrmaW6AjVEf",
#     "type": "audio_features",
#     "uri": "spotify:track:7CWiWkccuRRdrmaW6AjVEf",
#     "valence": 0.491
# }
# Kiss It Better: 0UHB9METy4VCXNgkcGqHqS
# 68
# {
#     "acousticness": 0.272,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0UHB9METy4VCXNgkcGqHqS",
#     "danceability": 0.619,
#     "duration_ms": 253080,
#     "energy": 0.806,
#     "id": "0UHB9METy4VCXNgkcGqHqS",
#     "instrumentalness": 0,
#     "key": 3,
#     "liveness": 0.0671,
#     "loudness": -4.8,
#     "mode": 0,
#     "speechiness": 0.0483,
#     "tempo": 95.0,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0UHB9METy4VCXNgkcGqHqS",
#     "type": "audio_features",
#     "uri": "spotify:track:0UHB9METy4VCXNgkcGqHqS",
#     "valence": 0.877
# }
# Forever Young: 56bHclo7YNvpujMveLElQn
# 66
# {
#     "acousticness": 0.0426,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/56bHclo7YNvpujMveLElQn",
#     "danceability": 0.6,
#     "duration_ms": 237077,
#     "energy": 0.96,
#     "id": "56bHclo7YNvpujMveLElQn",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.0882,
#     "loudness": -1.807,
#     "mode": 1,
#     "speechiness": 0.095,
#     "tempo": 109.863,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/56bHclo7YNvpujMveLElQn",
#     "type": "audio_features",
#     "uri": "spotify:track:56bHclo7YNvpujMveLElQn",
#     "valence": 0.503
# }
# Hair Up: 2986J0T5CGwJGY3aqgANtE
# 61
# {
#     "acousticness": 0.0106,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2986J0T5CGwJGY3aqgANtE",
#     "danceability": 0.687,
#     "duration_ms": 178360,
#     "energy": 0.58,
#     "id": "2986J0T5CGwJGY3aqgANtE",
#     "instrumentalness": 7.65e-06,
#     "key": 7,
#     "liveness": 0.0935,
#     "loudness": -8.103,
#     "mode": 1,
#     "speechiness": 0.0483,
#     "tempo": 150.055,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2986J0T5CGwJGY3aqgANtE",
#     "type": "audio_features",
#     "uri": "spotify:track:2986J0T5CGwJGY3aqgANtE",
#     "valence": 0.341
# }
# Work It: 3jagJCUbdqhDSPuxP8cAqF
# 69
# {
#     "acousticness": 0.0778,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3jagJCUbdqhDSPuxP8cAqF",
#     "danceability": 0.884,
#     "duration_ms": 263227,
#     "energy": 0.677,
#     "id": "3jagJCUbdqhDSPuxP8cAqF",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.0732,
#     "loudness": -5.603,
#     "mode": 1,
#     "speechiness": 0.283,
#     "tempo": 101.868,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3jagJCUbdqhDSPuxP8cAqF",
#     "type": "audio_features",
#     "uri": "spotify:track:3jagJCUbdqhDSPuxP8cAqF",
#     "valence": 0.584
# }
# In the Name of Love: 23L5CiUhw2jV1OIMwthR3S
# 78
# {
#     "acousticness": 0.109,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/23L5CiUhw2jV1OIMwthR3S",
#     "danceability": 0.501,
#     "duration_ms": 195707,
#     "energy": 0.519,
#     "id": "23L5CiUhw2jV1OIMwthR3S",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.454,
#     "loudness": -5.88,
#     "mode": 0,
#     "speechiness": 0.0409,
#     "tempo": 133.99,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/23L5CiUhw2jV1OIMwthR3S",
#     "type": "audio_features",
#     "uri": "spotify:track:23L5CiUhw2jV1OIMwthR3S",
#     "valence": 0.168
# }
# Forever ... (is a long time): 6BORJ0ZazxMBpM3cWg79Id
# 69
# {
#     "acousticness": 0.746,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6BORJ0ZazxMBpM3cWg79Id",
#     "danceability": 0.509,
#     "duration_ms": 167904,
#     "energy": 0.265,
#     "id": "6BORJ0ZazxMBpM3cWg79Id",
#     "instrumentalness": 1.08e-06,
#     "key": 2,
#     "liveness": 0.198,
#     "loudness": -9.716,
#     "mode": 0,
#     "speechiness": 0.0344,
#     "tempo": 70.028,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6BORJ0ZazxMBpM3cWg79Id",
#     "type": "audio_features",
#     "uri": "spotify:track:6BORJ0ZazxMBpM3cWg79Id",
#     "valence": 0.291
# }
# Broke Leg (with Quavo & Tyga): 5CKtlUULFD5aPVX4PL02H6
# 61
# {
#     "acousticness": 0.226,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5CKtlUULFD5aPVX4PL02H6",
#     "danceability": 0.851,
#     "duration_ms": 165605,
#     "energy": 0.85,
#     "id": "5CKtlUULFD5aPVX4PL02H6",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.145,
#     "loudness": -3.4,
#     "mode": 1,
#     "speechiness": 0.0904,
#     "tempo": 99.975,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5CKtlUULFD5aPVX4PL02H6",
#     "type": "audio_features",
#     "uri": "spotify:track:5CKtlUULFD5aPVX4PL02H6",
#     "valence": 0.642
# }
# Uncle John's Band: 1pBPTKMykvrbCz5J5tPTsd
# 0
# {
#     "acousticness": 0.496,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1pBPTKMykvrbCz5J5tPTsd",
#     "danceability": 0.701,
#     "duration_ms": 284910,
#     "energy": 0.316,
#     "id": "1pBPTKMykvrbCz5J5tPTsd",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.121,
#     "loudness": -14.723,
#     "mode": 1,
#     "speechiness": 0.0843,
#     "tempo": 136.73,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1pBPTKMykvrbCz5J5tPTsd",
#     "type": "audio_features",
#     "uri": "spotify:track:1pBPTKMykvrbCz5J5tPTsd",
#     "valence": 0.889
# }
# Suite In E Minor For Lute, BWV 996 - Arr. Segovia: 2. Allemande: 21zOFoqYc4u1A2vFk2zXf3
# 12
# {
#     "acousticness": 0.987,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/21zOFoqYc4u1A2vFk2zXf3",
#     "danceability": 0.495,
#     "duration_ms": 142693,
#     "energy": 0.105,
#     "id": "21zOFoqYc4u1A2vFk2zXf3",
#     "instrumentalness": 0.871,
#     "key": 9,
#     "liveness": 0.0943,
#     "loudness": -27.762,
#     "mode": 0,
#     "speechiness": 0.0546,
#     "tempo": 140.222,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/21zOFoqYc4u1A2vFk2zXf3",
#     "type": "audio_features",
#     "uri": "spotify:track:21zOFoqYc4u1A2vFk2zXf3",
#     "valence": 0.855
# }
# Ya Me Enteré: 4ggabbjjuHrG06SsYnqvEs
# 75
# {
#     "acousticness": 0.835,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4ggabbjjuHrG06SsYnqvEs",
#     "danceability": 0.657,
#     "duration_ms": 189347,
#     "energy": 0.591,
#     "id": "4ggabbjjuHrG06SsYnqvEs",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.248,
#     "loudness": -3.505,
#     "mode": 1,
#     "speechiness": 0.0297,
#     "tempo": 132.041,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4ggabbjjuHrG06SsYnqvEs",
#     "type": "audio_features",
#     "uri": "spotify:track:4ggabbjjuHrG06SsYnqvEs",
#     "valence": 0.687
# }
# Hillbilly: 2TlGQg8UKymxu3frqMXeO2
# 61
# {
#     "acousticness": 0.0651,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2TlGQg8UKymxu3frqMXeO2",
#     "danceability": 0.787,
#     "duration_ms": 150857,
#     "energy": 0.752,
#     "id": "2TlGQg8UKymxu3frqMXeO2",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.108,
#     "loudness": -5.293,
#     "mode": 1,
#     "speechiness": 0.105,
#     "tempo": 140.04,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2TlGQg8UKymxu3frqMXeO2",
#     "type": "audio_features",
#     "uri": "spotify:track:2TlGQg8UKymxu3frqMXeO2",
#     "valence": 0.199
# }
# Lay Me Down: 64GRDrL1efgXclrhVCeuA0
# 75
# {
#     "acousticness": 0.919,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/64GRDrL1efgXclrhVCeuA0",
#     "danceability": 0.468,
#     "duration_ms": 219536,
#     "energy": 0.19,
#     "id": "64GRDrL1efgXclrhVCeuA0",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.107,
#     "loudness": -11.138,
#     "mode": 1,
#     "speechiness": 0.0373,
#     "tempo": 125.319,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/64GRDrL1efgXclrhVCeuA0",
#     "type": "audio_features",
#     "uri": "spotify:track:64GRDrL1efgXclrhVCeuA0",
#     "valence": 0.326
# }
# Just Another Day In Paradise: 4LlNoNZflek4hZyZigCxpW
# 60
# {
#     "acousticness": 0.351,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4LlNoNZflek4hZyZigCxpW",
#     "danceability": 0.596,
#     "duration_ms": 233880,
#     "energy": 0.706,
#     "id": "4LlNoNZflek4hZyZigCxpW",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.36,
#     "loudness": -5.562,
#     "mode": 1,
#     "speechiness": 0.0262,
#     "tempo": 146.088,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4LlNoNZflek4hZyZigCxpW",
#     "type": "audio_features",
#     "uri": "spotify:track:4LlNoNZflek4hZyZigCxpW",
#     "valence": 0.704
# }
# Tokyo Drift (Fast & Furious) - From "The Fast And The Furious: Tokyo Drift" Soundtrack: 5iJfzXKvQXlYOBtEQhEmpA
# 63
# {
#     "acousticness": 0.178,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5iJfzXKvQXlYOBtEQhEmpA",
#     "danceability": 0.761,
#     "duration_ms": 255173,
#     "energy": 0.892,
#     "id": "5iJfzXKvQXlYOBtEQhEmpA",
#     "instrumentalness": 4.19e-05,
#     "key": 6,
#     "liveness": 0.0712,
#     "loudness": -5.354,
#     "mode": 1,
#     "speechiness": 0.133,
#     "tempo": 127.04,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5iJfzXKvQXlYOBtEQhEmpA",
#     "type": "audio_features",
#     "uri": "spotify:track:5iJfzXKvQXlYOBtEQhEmpA",
#     "valence": 0.935
# }
# Who Needs Love: 2ktxr00GpTtbMNeBjNeY8D
# 77
# {
#     "acousticness": 0.763,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2ktxr00GpTtbMNeBjNeY8D",
#     "danceability": 0.85,
#     "duration_ms": 158532,
#     "energy": 0.516,
#     "id": "2ktxr00GpTtbMNeBjNeY8D",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.0896,
#     "loudness": -7.664,
#     "mode": 0,
#     "speechiness": 0.0714,
#     "tempo": 108.963,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2ktxr00GpTtbMNeBjNeY8D",
#     "type": "audio_features",
#     "uri": "spotify:track:2ktxr00GpTtbMNeBjNeY8D",
#     "valence": 0.874
# }
# Ignorantes: 3wYRLYuO1M88d8woWUIxct
# 91
# {
#     "acousticness": 0.267,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3wYRLYuO1M88d8woWUIxct",
#     "danceability": 0.85,
#     "duration_ms": 210607,
#     "energy": 0.536,
#     "id": "3wYRLYuO1M88d8woWUIxct",
#     "instrumentalness": 3.89e-05,
#     "key": 1,
#     "liveness": 0.0996,
#     "loudness": -5.161,
#     "mode": 1,
#     "speechiness": 0.0599,
#     "tempo": 96.029,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3wYRLYuO1M88d8woWUIxct",
#     "type": "audio_features",
#     "uri": "spotify:track:3wYRLYuO1M88d8woWUIxct",
#     "valence": 0.505
# }
# UFOF: 1DXvEWgI1xoxmKv2Zd3pNE
# 59
# {
#     "acousticness": 0.638,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1DXvEWgI1xoxmKv2Zd3pNE",
#     "danceability": 0.623,
#     "duration_ms": 188413,
#     "energy": 0.613,
#     "id": "1DXvEWgI1xoxmKv2Zd3pNE",
#     "instrumentalness": 0.572,
#     "key": 10,
#     "liveness": 0.143,
#     "loudness": -9.241,
#     "mode": 0,
#     "speechiness": 0.0309,
#     "tempo": 147.168,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1DXvEWgI1xoxmKv2Zd3pNE",
#     "type": "audio_features",
#     "uri": "spotify:track:1DXvEWgI1xoxmKv2Zd3pNE",
#     "valence": 0.745
# }
# Clean & Pure White Noise: 18lKp9uRyR2xJZFvg8ZWUC
# 61
# {
#     "acousticness": 0.455,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/18lKp9uRyR2xJZFvg8ZWUC",
#     "danceability": 0,
#     "duration_ms": 150000,
#     "energy": 0.0924,
#     "id": "18lKp9uRyR2xJZFvg8ZWUC",
#     "instrumentalness": 0.408,
#     "key": 1,
#     "liveness": 0.111,
#     "loudness": -26.764,
#     "mode": 1,
#     "speechiness": 0,
#     "tempo": 0,
#     "time_signature": 0,
#     "track_href": "https://api.spotify.com/v1/tracks/18lKp9uRyR2xJZFvg8ZWUC",
#     "type": "audio_features",
#     "uri": "spotify:track:18lKp9uRyR2xJZFvg8ZWUC",
#     "valence": 0
# }
# Another In The Fire - Live: 5PmHmU5AaBy9ld3bdQkD96
# 63
# {
#     "acousticness": 0.000614,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5PmHmU5AaBy9ld3bdQkD96",
#     "danceability": 0.451,
#     "duration_ms": 393360,
#     "energy": 0.688,
#     "id": "5PmHmU5AaBy9ld3bdQkD96",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.141,
#     "loudness": -7.843,
#     "mode": 1,
#     "speechiness": 0.0358,
#     "tempo": 135.066,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5PmHmU5AaBy9ld3bdQkD96",
#     "type": "audio_features",
#     "uri": "spotify:track:5PmHmU5AaBy9ld3bdQkD96",
#     "valence": 0.0827
# }
# Shepherd of Fire: 1fQaoh3imrMunWVZh5kf90
# 67
# {
#     "acousticness": 0.000332,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1fQaoh3imrMunWVZh5kf90",
#     "danceability": 0.576,
#     "duration_ms": 323800,
#     "energy": 0.906,
#     "id": "1fQaoh3imrMunWVZh5kf90",
#     "instrumentalness": 0.0614,
#     "key": 2,
#     "liveness": 0.0908,
#     "loudness": -7.677,
#     "mode": 1,
#     "speechiness": 0.0571,
#     "tempo": 127.935,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1fQaoh3imrMunWVZh5kf90",
#     "type": "audio_features",
#     "uri": "spotify:track:1fQaoh3imrMunWVZh5kf90",
#     "valence": 0.211
# }
# Waiting On the World to Change: 5imShWWzwqfAJ9gXFpGAQh
# 72
# {
#     "acousticness": 0.159,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5imShWWzwqfAJ9gXFpGAQh",
#     "danceability": 0.577,
#     "duration_ms": 201173,
#     "energy": 0.756,
#     "id": "5imShWWzwqfAJ9gXFpGAQh",
#     "instrumentalness": 0.000232,
#     "key": 2,
#     "liveness": 0.249,
#     "loudness": -5.82,
#     "mode": 1,
#     "speechiness": 0.115,
#     "tempo": 176.75,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5imShWWzwqfAJ9gXFpGAQh",
#     "type": "audio_features",
#     "uri": "spotify:track:5imShWWzwqfAJ9gXFpGAQh",
#     "valence": 0.663
# }
# Baby Pluto: 0MBbqhCETOfzONwgSAtKpI
# 68
# {
#     "acousticness": 0.135,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0MBbqhCETOfzONwgSAtKpI",
#     "danceability": 0.772,
#     "duration_ms": 210261,
#     "energy": 0.634,
#     "id": "0MBbqhCETOfzONwgSAtKpI",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.432,
#     "loudness": -6.101,
#     "mode": 0,
#     "speechiness": 0.212,
#     "tempo": 160.052,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0MBbqhCETOfzONwgSAtKpI",
#     "type": "audio_features",
#     "uri": "spotify:track:0MBbqhCETOfzONwgSAtKpI",
#     "valence": 0.671
# }
# The Only Exception: 7JIuqL4ZqkpfGKQhYlrirs
# 69
# {
#     "acousticness": 0.144,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7JIuqL4ZqkpfGKQhYlrirs",
#     "danceability": 0.452,
#     "duration_ms": 267653,
#     "energy": 0.563,
#     "id": "7JIuqL4ZqkpfGKQhYlrirs",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.143,
#     "loudness": -6.607,
#     "mode": 1,
#     "speechiness": 0.0272,
#     "tempo": 137.715,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/7JIuqL4ZqkpfGKQhYlrirs",
#     "type": "audio_features",
#     "uri": "spotify:track:7JIuqL4ZqkpfGKQhYlrirs",
#     "valence": 0.209
# }
# This Is Me: 45aBsnKRWUzhwbcqOJLwfe
# 76
# {
#     "acousticness": 0.00583,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/45aBsnKRWUzhwbcqOJLwfe",
#     "danceability": 0.284,
#     "duration_ms": 234707,
#     "energy": 0.704,
#     "id": "45aBsnKRWUzhwbcqOJLwfe",
#     "instrumentalness": 0.000115,
#     "key": 2,
#     "liveness": 0.0424,
#     "loudness": -7.276,
#     "mode": 1,
#     "speechiness": 0.186,
#     "tempo": 191.702,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/45aBsnKRWUzhwbcqOJLwfe",
#     "type": "audio_features",
#     "uri": "spotify:track:45aBsnKRWUzhwbcqOJLwfe",
#     "valence": 0.1
# }
# Slide: 0nnwn7LWHCAu09jfuH1xTA
# 68
# {
#     "acousticness": 0.00483,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0nnwn7LWHCAu09jfuH1xTA",
#     "danceability": 0.395,
#     "duration_ms": 212067,
#     "energy": 0.843,
#     "id": "0nnwn7LWHCAu09jfuH1xTA",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.0404,
#     "loudness": -4.476,
#     "mode": 1,
#     "speechiness": 0.0374,
#     "tempo": 112.423,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0nnwn7LWHCAu09jfuH1xTA",
#     "type": "audio_features",
#     "uri": "spotify:track:0nnwn7LWHCAu09jfuH1xTA",
#     "valence": 0.481
# }
# En Cero: 51uLQESb4VnYAbs5WtGxho
# 70
# {
#     "acousticness": 0.156,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/51uLQESb4VnYAbs5WtGxho",
#     "danceability": 0.733,
#     "duration_ms": 223587,
#     "energy": 0.782,
#     "id": "51uLQESb4VnYAbs5WtGxho",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.286,
#     "loudness": -4.788,
#     "mode": 1,
#     "speechiness": 0.0386,
#     "tempo": 93.021,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/51uLQESb4VnYAbs5WtGxho",
#     "type": "audio_features",
#     "uri": "spotify:track:51uLQESb4VnYAbs5WtGxho",
#     "valence": 0.634
# }
# Ni**as In Paris: 2KpCpk6HjXXLb7nnXoXA5O
# 62
# {
#     "acousticness": 0.0763,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2KpCpk6HjXXLb7nnXoXA5O",
#     "danceability": 0.757,
#     "duration_ms": 219320,
#     "energy": 0.882,
#     "id": "2KpCpk6HjXXLb7nnXoXA5O",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.251,
#     "loudness": -6.125,
#     "mode": 1,
#     "speechiness": 0.248,
#     "tempo": 140.047,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2KpCpk6HjXXLb7nnXoXA5O",
#     "type": "audio_features",
#     "uri": "spotify:track:2KpCpk6HjXXLb7nnXoXA5O",
#     "valence": 0.684
# }
# Suite: Judy Blue Eyes - Remastered: 2PuUFT13yCzUOZun94WOXv
# 66
# {
#     "acousticness": 0.469,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2PuUFT13yCzUOZun94WOXv",
#     "danceability": 0.451,
#     "duration_ms": 444053,
#     "energy": 0.364,
#     "id": "2PuUFT13yCzUOZun94WOXv",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.197,
#     "loudness": -13.126,
#     "mode": 1,
#     "speechiness": 0.0436,
#     "tempo": 154.206,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2PuUFT13yCzUOZun94WOXv",
#     "type": "audio_features",
#     "uri": "spotify:track:2PuUFT13yCzUOZun94WOXv",
#     "valence": 0.298
# }
# Demons: 4RtYR0ExTUZSpHIuoUJBDR
# 51
# {
#     "acousticness": 0.665,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4RtYR0ExTUZSpHIuoUJBDR",
#     "danceability": 0.708,
#     "duration_ms": 165112,
#     "energy": 0.489,
#     "id": "4RtYR0ExTUZSpHIuoUJBDR",
#     "instrumentalness": 0.000138,
#     "key": 5,
#     "liveness": 0.302,
#     "loudness": -7.608,
#     "mode": 0,
#     "speechiness": 0.0366,
#     "tempo": 142.925,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4RtYR0ExTUZSpHIuoUJBDR",
#     "type": "audio_features",
#     "uri": "spotify:track:4RtYR0ExTUZSpHIuoUJBDR",
#     "valence": 0.771
# }
# Stay A Little Longer: 23EkfwUdsRIz7jAZIcC8gb
# 62
# {
#     "acousticness": 0.0377,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/23EkfwUdsRIz7jAZIcC8gb",
#     "danceability": 0.557,
#     "duration_ms": 335480,
#     "energy": 0.886,
#     "id": "23EkfwUdsRIz7jAZIcC8gb",
#     "instrumentalness": 0.108,
#     "key": 6,
#     "liveness": 0.163,
#     "loudness": -5.356,
#     "mode": 1,
#     "speechiness": 0.0302,
#     "tempo": 96.989,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/23EkfwUdsRIz7jAZIcC8gb",
#     "type": "audio_features",
#     "uri": "spotify:track:23EkfwUdsRIz7jAZIcC8gb",
#     "valence": 0.545
# }
# Your Peace (feat. Lil Baby): 6uNuT1YKpKjgZOOKiY4Nmf
# 68
# {
#     "acousticness": 0.0105,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6uNuT1YKpKjgZOOKiY4Nmf",
#     "danceability": 0.51,
#     "duration_ms": 183933,
#     "energy": 0.624,
#     "id": "6uNuT1YKpKjgZOOKiY4Nmf",
#     "instrumentalness": 0,
#     "key": 6,
#     "liveness": 0.102,
#     "loudness": -5.977,
#     "mode": 0,
#     "speechiness": 0.16,
#     "tempo": 196.059,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6uNuT1YKpKjgZOOKiY4Nmf",
#     "type": "audio_features",
#     "uri": "spotify:track:6uNuT1YKpKjgZOOKiY4Nmf",
#     "valence": 0.575
# }
# Estamos Bien: 2OWVCFTolecLiGZPquvWvT
# 75
# {
#     "acousticness": 0.821,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2OWVCFTolecLiGZPquvWvT",
#     "danceability": 0.759,
#     "duration_ms": 208080,
#     "energy": 0.536,
#     "id": "2OWVCFTolecLiGZPquvWvT",
#     "instrumentalness": 4.57e-06,
#     "key": 9,
#     "liveness": 0.107,
#     "loudness": -6.663,
#     "mode": 0,
#     "speechiness": 0.173,
#     "tempo": 119.883,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2OWVCFTolecLiGZPquvWvT",
#     "type": "audio_features",
#     "uri": "spotify:track:2OWVCFTolecLiGZPquvWvT",
#     "valence": 0.439
# }
# Where I Come From: 10ps1I1sIMRNZW11eceN7W
# 60
# {
#     "acousticness": 0.0108,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/10ps1I1sIMRNZW11eceN7W",
#     "danceability": 0.62,
#     "duration_ms": 201840,
#     "energy": 0.852,
#     "id": "10ps1I1sIMRNZW11eceN7W",
#     "instrumentalness": 4.94e-06,
#     "key": 1,
#     "liveness": 0.279,
#     "loudness": -4.203,
#     "mode": 1,
#     "speechiness": 0.0308,
#     "tempo": 90.038,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/10ps1I1sIMRNZW11eceN7W",
#     "type": "audio_features",
#     "uri": "spotify:track:10ps1I1sIMRNZW11eceN7W",
#     "valence": 0.479
# }
# No More Parties In LA: 0zLClc0emc6qUeV1p5nc99
# 64
# {
#     "acousticness": 0.246,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0zLClc0emc6qUeV1p5nc99",
#     "danceability": 0.508,
#     "duration_ms": 374413,
#     "energy": 0.921,
#     "id": "0zLClc0emc6qUeV1p5nc99",
#     "instrumentalness": 0,
#     "key": 5,
#     "liveness": 0.221,
#     "loudness": -1.644,
#     "mode": 1,
#     "speechiness": 0.303,
#     "tempo": 93.058,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0zLClc0emc6qUeV1p5nc99",
#     "type": "audio_features",
#     "uri": "spotify:track:0zLClc0emc6qUeV1p5nc99",
#     "valence": 0.681
# }
# Dancing On My Own - Radio Edit: 7g13jf3zqlP5S68Voo5v9m
# 61
# {
#     "acousticness": 0.00202,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7g13jf3zqlP5S68Voo5v9m",
#     "danceability": 0.573,
#     "duration_ms": 278080,
#     "energy": 0.926,
#     "id": "7g13jf3zqlP5S68Voo5v9m",
#     "instrumentalness": 0.0117,
#     "key": 6,
#     "liveness": 0.127,
#     "loudness": -6.045,
#     "mode": 1,
#     "speechiness": 0.0342,
#     "tempo": 117.048,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7g13jf3zqlP5S68Voo5v9m",
#     "type": "audio_features",
#     "uri": "spotify:track:7g13jf3zqlP5S68Voo5v9m",
#     "valence": 0.219
# }
# Cannibal: 3JTMWdhcJPiegDSe7SvZS3
# 77
# {
#     "acousticness": 0.0078,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3JTMWdhcJPiegDSe7SvZS3",
#     "danceability": 0.71,
#     "duration_ms": 194253,
#     "energy": 0.68,
#     "id": "3JTMWdhcJPiegDSe7SvZS3",
#     "instrumentalness": 0.0165,
#     "key": 1,
#     "liveness": 0.0493,
#     "loudness": -4.676,
#     "mode": 1,
#     "speechiness": 0.106,
#     "tempo": 129.971,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3JTMWdhcJPiegDSe7SvZS3",
#     "type": "audio_features",
#     "uri": "spotify:track:3JTMWdhcJPiegDSe7SvZS3",
#     "valence": 0.571
# }
# Unlove You: 1OAVOMutu0LdzV8dEv7Rb9
# 54
# {
#     "acousticness": 0.592,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1OAVOMutu0LdzV8dEv7Rb9",
#     "danceability": 0.514,
#     "duration_ms": 201581,
#     "energy": 0.662,
#     "id": "1OAVOMutu0LdzV8dEv7Rb9",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.32,
#     "loudness": -3.85,
#     "mode": 1,
#     "speechiness": 0.153,
#     "tempo": 97.016,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1OAVOMutu0LdzV8dEv7Rb9",
#     "type": "audio_features",
#     "uri": "spotify:track:1OAVOMutu0LdzV8dEv7Rb9",
#     "valence": 0.675
# }
# my boy: 1RGasjWLZ4qMN7wbtkLa3u
# 78
# {
#     "acousticness": 0.472,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1RGasjWLZ4qMN7wbtkLa3u",
#     "danceability": 0.692,
#     "duration_ms": 170852,
#     "energy": 0.394,
#     "id": "1RGasjWLZ4qMN7wbtkLa3u",
#     "instrumentalness": 0.000191,
#     "key": 11,
#     "liveness": 0.117,
#     "loudness": -8.745,
#     "mode": 0,
#     "speechiness": 0.207,
#     "tempo": 89.936,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1RGasjWLZ4qMN7wbtkLa3u",
#     "type": "audio_features",
#     "uri": "spotify:track:1RGasjWLZ4qMN7wbtkLa3u",
#     "valence": 0.324
# }
# Sultans of Swing: 5x5QjgqY5jRiiMcB1gkueB
# 0
# {
#     "acousticness": 0.0722,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5x5QjgqY5jRiiMcB1gkueB",
#     "danceability": 0.726,
#     "duration_ms": 348760,
#     "energy": 0.802,
#     "id": "5x5QjgqY5jRiiMcB1gkueB",
#     "instrumentalness": 0.0348,
#     "key": 5,
#     "liveness": 0.339,
#     "loudness": -10.059,
#     "mode": 1,
#     "speechiness": 0.0302,
#     "tempo": 148.208,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5x5QjgqY5jRiiMcB1gkueB",
#     "type": "audio_features",
#     "uri": "spotify:track:5x5QjgqY5jRiiMcB1gkueB",
#     "valence": 0.925
# }
# Weak: 71EHOyEOhNx1SzTebRRyng
# 66
# {
#     "acousticness": 0.107,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/71EHOyEOhNx1SzTebRRyng",
#     "danceability": 0.693,
#     "duration_ms": 291907,
#     "energy": 0.533,
#     "id": "71EHOyEOhNx1SzTebRRyng",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.0695,
#     "loudness": -10.954,
#     "mode": 0,
#     "speechiness": 0.0402,
#     "tempo": 127.661,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/71EHOyEOhNx1SzTebRRyng",
#     "type": "audio_features",
#     "uri": "spotify:track:71EHOyEOhNx1SzTebRRyng",
#     "valence": 0.568
# }
# En Mis Dedos un Gallito: 0w05EANAQs2Cf3xj5daRPY
# 58
# {
#     "acousticness": 0.393,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0w05EANAQs2Cf3xj5daRPY",
#     "danceability": 0.693,
#     "duration_ms": 188401,
#     "energy": 0.587,
#     "id": "0w05EANAQs2Cf3xj5daRPY",
#     "instrumentalness": 3.74e-06,
#     "key": 8,
#     "liveness": 0.0999,
#     "loudness": -4.067,
#     "mode": 0,
#     "speechiness": 0.0278,
#     "tempo": 150.036,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/0w05EANAQs2Cf3xj5daRPY",
#     "type": "audio_features",
#     "uri": "spotify:track:0w05EANAQs2Cf3xj5daRPY",
#     "valence": 0.689
# }
# Are You Gonna Be My Girl: 305WCRhhS10XUcH6AEwZk6
# 74
# {
#     "acousticness": 0.00148,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/305WCRhhS10XUcH6AEwZk6",
#     "danceability": 0.613,
#     "duration_ms": 213800,
#     "energy": 0.953,
#     "id": "305WCRhhS10XUcH6AEwZk6",
#     "instrumentalness": 0.000582,
#     "key": 2,
#     "liveness": 0.152,
#     "loudness": -3.435,
#     "mode": 1,
#     "speechiness": 0.0855,
#     "tempo": 105.046,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/305WCRhhS10XUcH6AEwZk6",
#     "type": "audio_features",
#     "uri": "spotify:track:305WCRhhS10XUcH6AEwZk6",
#     "valence": 0.537
# }
# Season Ticket Holder (feat. D. Wade, Raphael Saadiq & UD): 7APQE45T3fsAPbfFuEtoQE
# 60
# {
#     "acousticness": 0.156,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7APQE45T3fsAPbfFuEtoQE",
#     "danceability": 0.622,
#     "duration_ms": 242119,
#     "energy": 0.85,
#     "id": "7APQE45T3fsAPbfFuEtoQE",
#     "instrumentalness": 0,
#     "key": 6,
#     "liveness": 0.189,
#     "loudness": -3.616,
#     "mode": 1,
#     "speechiness": 0.249,
#     "tempo": 78.959,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7APQE45T3fsAPbfFuEtoQE",
#     "type": "audio_features",
#     "uri": "spotify:track:7APQE45T3fsAPbfFuEtoQE",
#     "valence": 0.697
# }
# Even Though I'm Leaving: 5aZQrb2TXWEh9uZR4HEY3r
# 77
# {
#     "acousticness": 0.225,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5aZQrb2TXWEh9uZR4HEY3r",
#     "danceability": 0.554,
#     "duration_ms": 225253,
#     "energy": 0.755,
#     "id": "5aZQrb2TXWEh9uZR4HEY3r",
#     "instrumentalness": 0,
#     "key": 2,
#     "liveness": 0.301,
#     "loudness": -6.04,
#     "mode": 1,
#     "speechiness": 0.0319,
#     "tempo": 77.962,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5aZQrb2TXWEh9uZR4HEY3r",
#     "type": "audio_features",
#     "uri": "spotify:track:5aZQrb2TXWEh9uZR4HEY3r",
#     "valence": 0.624
# }
# Knockin' On Heaven's Door: 4JiEyzf0Md7KEFFGWDDdCr
# 76
# {
#     "acousticness": 0.0211,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4JiEyzf0Md7KEFFGWDDdCr",
#     "danceability": 0.496,
#     "duration_ms": 336000,
#     "energy": 0.739,
#     "id": "4JiEyzf0Md7KEFFGWDDdCr",
#     "instrumentalness": 0.00444,
#     "key": 6,
#     "liveness": 0.106,
#     "loudness": -7.193,
#     "mode": 1,
#     "speechiness": 0.0415,
#     "tempo": 132.41,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4JiEyzf0Md7KEFFGWDDdCr",
#     "type": "audio_features",
#     "uri": "spotify:track:4JiEyzf0Md7KEFFGWDDdCr",
#     "valence": 0.378
# }
# High Cost Of Living: 73sWpECi7iZrcISLSRxuaH
# 60
# {
#     "acousticness": 0.0114,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/73sWpECi7iZrcISLSRxuaH",
#     "danceability": 0.628,
#     "duration_ms": 345120,
#     "energy": 0.601,
#     "id": "73sWpECi7iZrcISLSRxuaH",
#     "instrumentalness": 2.63e-05,
#     "key": 0,
#     "liveness": 0.32,
#     "loudness": -7.036,
#     "mode": 1,
#     "speechiness": 0.0368,
#     "tempo": 86.006,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/73sWpECi7iZrcISLSRxuaH",
#     "type": "audio_features",
#     "uri": "spotify:track:73sWpECi7iZrcISLSRxuaH",
#     "valence": 0.396
# }
# Estamos Arriba: 0bCPJsVGDxPYwQMDZMi4NW
# 71
# {
#     "acousticness": 0.186,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0bCPJsVGDxPYwQMDZMi4NW",
#     "danceability": 0.853,
#     "duration_ms": 225694,
#     "energy": 0.818,
#     "id": "0bCPJsVGDxPYwQMDZMi4NW",
#     "instrumentalness": 0.000255,
#     "key": 11,
#     "liveness": 0.18,
#     "loudness": -3.6,
#     "mode": 1,
#     "speechiness": 0.0922,
#     "tempo": 149.839,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0bCPJsVGDxPYwQMDZMi4NW",
#     "type": "audio_features",
#     "uri": "spotify:track:0bCPJsVGDxPYwQMDZMi4NW",
#     "valence": 0.546
# }
# Solita: 7rwX0O3RlxqqIjQM8evm5E
# 73
# {
#     "acousticness": 0.0564,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7rwX0O3RlxqqIjQM8evm5E",
#     "danceability": 0.807,
#     "duration_ms": 311726,
#     "energy": 0.633,
#     "id": "7rwX0O3RlxqqIjQM8evm5E",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.107,
#     "loudness": -6.016,
#     "mode": 0,
#     "speechiness": 0.0929,
#     "tempo": 138.038,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7rwX0O3RlxqqIjQM8evm5E",
#     "type": "audio_features",
#     "uri": "spotify:track:7rwX0O3RlxqqIjQM8evm5E",
#     "valence": 0.325
# }
# Turn Up the Music: 4bb2UdCvi9LynD4rWvE06T
# 55
# {
#     "acousticness": 0.0957,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4bb2UdCvi9LynD4rWvE06T",
#     "danceability": 0.531,
#     "duration_ms": 176600,
#     "energy": 0.827,
#     "id": "4bb2UdCvi9LynD4rWvE06T",
#     "instrumentalness": 1.84e-06,
#     "key": 7,
#     "liveness": 0.074,
#     "loudness": -3.7,
#     "mode": 1,
#     "speechiness": 0.081,
#     "tempo": 183.977,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4bb2UdCvi9LynD4rWvE06T",
#     "type": "audio_features",
#     "uri": "spotify:track:4bb2UdCvi9LynD4rWvE06T",
#     "valence": 0.801
# }
# Heartbeat (BTS World Original Soundtrack): 5EgYDyMDCi8X0zDydTF7Rb
# 68
# {
#     "acousticness": 0.39,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5EgYDyMDCi8X0zDydTF7Rb",
#     "danceability": 0.437,
#     "duration_ms": 253304,
#     "energy": 0.716,
#     "id": "5EgYDyMDCi8X0zDydTF7Rb",
#     "instrumentalness": 0,
#     "key": 5,
#     "liveness": 0.208,
#     "loudness": -4.306,
#     "mode": 1,
#     "speechiness": 0.05,
#     "tempo": 170.094,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5EgYDyMDCi8X0zDydTF7Rb",
#     "type": "audio_features",
#     "uri": "spotify:track:5EgYDyMDCi8X0zDydTF7Rb",
#     "valence": 0.307
# }
# Last Resort: 5W8YXBz9MTIDyrpYaCg2Ky
# 78
# {
#     "acousticness": 0.000481,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5W8YXBz9MTIDyrpYaCg2Ky",
#     "danceability": 0.589,
#     "duration_ms": 199907,
#     "energy": 0.89,
#     "id": "5W8YXBz9MTIDyrpYaCg2Ky",
#     "instrumentalness": 0.00082,
#     "key": 4,
#     "liveness": 0.201,
#     "loudness": -3.719,
#     "mode": 0,
#     "speechiness": 0.0603,
#     "tempo": 90.598,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5W8YXBz9MTIDyrpYaCg2Ky",
#     "type": "audio_features",
#     "uri": "spotify:track:5W8YXBz9MTIDyrpYaCg2Ky",
#     "valence": 0.692
# }
# Ashley (with DaBaby): 4gH4e5ENzVDg4N8fOp2vDP
# 68
# {
#     "acousticness": 0.00284,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4gH4e5ENzVDg4N8fOp2vDP",
#     "danceability": 0.884,
#     "duration_ms": 151859,
#     "energy": 0.807,
#     "id": "4gH4e5ENzVDg4N8fOp2vDP",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.111,
#     "loudness": -3.462,
#     "mode": 0,
#     "speechiness": 0.325,
#     "tempo": 144.018,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4gH4e5ENzVDg4N8fOp2vDP",
#     "type": "audio_features",
#     "uri": "spotify:track:4gH4e5ENzVDg4N8fOp2vDP",
#     "valence": 0.916
# }
# All Of The Lights: 22L7bfCiAkJo5xGSQgmiIO
# 74
# {
#     "acousticness": 0.0796,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/22L7bfCiAkJo5xGSQgmiIO",
#     "danceability": 0.541,
#     "duration_ms": 299613,
#     "energy": 0.803,
#     "id": "22L7bfCiAkJo5xGSQgmiIO",
#     "instrumentalness": 1.71e-05,
#     "key": 1,
#     "liveness": 0.176,
#     "loudness": -3.284,
#     "mode": 1,
#     "speechiness": 0.0738,
#     "tempo": 142.135,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/22L7bfCiAkJo5xGSQgmiIO",
#     "type": "audio_features",
#     "uri": "spotify:track:22L7bfCiAkJo5xGSQgmiIO",
#     "valence": 0.221
# }
# Up Up & Away: 1RUTIdTnFs8lHSc0Zr4UJB
# 57
# {
#     "acousticness": 0.0722,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1RUTIdTnFs8lHSc0Zr4UJB",
#     "danceability": 0.66,
#     "duration_ms": 227347,
#     "energy": 0.881,
#     "id": "1RUTIdTnFs8lHSc0Zr4UJB",
#     "instrumentalness": 3.4e-05,
#     "key": 10,
#     "liveness": 0.362,
#     "loudness": -6.119,
#     "mode": 0,
#     "speechiness": 0.0849,
#     "tempo": 120.017,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1RUTIdTnFs8lHSc0Zr4UJB",
#     "type": "audio_features",
#     "uri": "spotify:track:1RUTIdTnFs8lHSc0Zr4UJB",
#     "valence": 0.586
# }
# Candy Paint: 32lItqlMi4LBhb4k0BaSaC
# 78
# {
#     "acousticness": 0.64,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/32lItqlMi4LBhb4k0BaSaC",
#     "danceability": 0.664,
#     "duration_ms": 227533,
#     "energy": 0.667,
#     "id": "32lItqlMi4LBhb4k0BaSaC",
#     "instrumentalness": 1.22e-06,
#     "key": 4,
#     "liveness": 0.0753,
#     "loudness": -5.941,
#     "mode": 1,
#     "speechiness": 0.154,
#     "tempo": 180.064,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/32lItqlMi4LBhb4k0BaSaC",
#     "type": "audio_features",
#     "uri": "spotify:track:32lItqlMi4LBhb4k0BaSaC",
#     "valence": 0.381
# }
# UN PESO: 7hynhxDoDpgMIV12JuVtNa
# 78
# {
#     "acousticness": 0.125,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/7hynhxDoDpgMIV12JuVtNa",
#     "danceability": 0.627,
#     "duration_ms": 277107,
#     "energy": 0.675,
#     "id": "7hynhxDoDpgMIV12JuVtNa",
#     "instrumentalness": 0,
#     "key": 5,
#     "liveness": 0.0784,
#     "loudness": -7.125,
#     "mode": 0,
#     "speechiness": 0.213,
#     "tempo": 79.31,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/7hynhxDoDpgMIV12JuVtNa",
#     "type": "audio_features",
#     "uri": "spotify:track:7hynhxDoDpgMIV12JuVtNa",
#     "valence": 0.961
# }
# 10,000 Degrees: 4nutwPQrK56fFmrAMgyPhz
# 60
# {
#     "acousticness": 0.0193,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4nutwPQrK56fFmrAMgyPhz",
#     "danceability": 0.72,
#     "duration_ms": 189109,
#     "energy": 0.727,
#     "id": "4nutwPQrK56fFmrAMgyPhz",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.107,
#     "loudness": -8.16,
#     "mode": 1,
#     "speechiness": 0.221,
#     "tempo": 77.991,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/4nutwPQrK56fFmrAMgyPhz",
#     "type": "audio_features",
#     "uri": "spotify:track:4nutwPQrK56fFmrAMgyPhz",
#     "valence": 0.277
# }
# UP THE SMOKE (with Offset): 3faAAUxohrxqYhPlneZ3XV
# 78
# {
#     "acousticness": 0.0506,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3faAAUxohrxqYhPlneZ3XV",
#     "danceability": 0.899,
#     "duration_ms": 188107,
#     "energy": 0.735,
#     "id": "3faAAUxohrxqYhPlneZ3XV",
#     "instrumentalness": 0,
#     "key": 4,
#     "liveness": 0.15,
#     "loudness": -7.719,
#     "mode": 1,
#     "speechiness": 0.4,
#     "tempo": 143.001,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3faAAUxohrxqYhPlneZ3XV",
#     "type": "audio_features",
#     "uri": "spotify:track:3faAAUxohrxqYhPlneZ3XV",
#     "valence": 0.884
# }
# ME! (feat. Brendon Urie of Panic! At The Disco): 2Rk4JlNc2TPmZe2af99d45
# 83
# {
#     "acousticness": 0.033,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2Rk4JlNc2TPmZe2af99d45",
#     "danceability": 0.61,
#     "duration_ms": 193000,
#     "energy": 0.83,
#     "id": "2Rk4JlNc2TPmZe2af99d45",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.118,
#     "loudness": -4.105,
#     "mode": 1,
#     "speechiness": 0.0571,
#     "tempo": 182.162,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2Rk4JlNc2TPmZe2af99d45",
#     "type": "audio_features",
#     "uri": "spotify:track:2Rk4JlNc2TPmZe2af99d45",
#     "valence": 0.728
# }
# Electric (feat. Khalid): 2mj7x99sNUsVHPBRK51zlG
# 71
# {
#     "acousticness": 0.738,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2mj7x99sNUsVHPBRK51zlG",
#     "danceability": 0.599,
#     "duration_ms": 246327,
#     "energy": 0.396,
#     "id": "2mj7x99sNUsVHPBRK51zlG",
#     "instrumentalness": 2.19e-05,
#     "key": 10,
#     "liveness": 0.102,
#     "loudness": -10.489,
#     "mode": 0,
#     "speechiness": 0.0392,
#     "tempo": 111.072,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2mj7x99sNUsVHPBRK51zlG",
#     "type": "audio_features",
#     "uri": "spotify:track:2mj7x99sNUsVHPBRK51zlG",
#     "valence": 0.134
# }
# La Modelo: 2SbzdGpOKlH3HIAGTWTbwU
# 69
# {
#     "acousticness": 0.241,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2SbzdGpOKlH3HIAGTWTbwU",
#     "danceability": 0.574,
#     "duration_ms": 255507,
#     "energy": 0.734,
#     "id": "2SbzdGpOKlH3HIAGTWTbwU",
#     "instrumentalness": 0.00806,
#     "key": 1,
#     "liveness": 0.0962,
#     "loudness": -2.697,
#     "mode": 1,
#     "speechiness": 0.0728,
#     "tempo": 98.023,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2SbzdGpOKlH3HIAGTWTbwU",
#     "type": "audio_features",
#     "uri": "spotify:track:2SbzdGpOKlH3HIAGTWTbwU",
#     "valence": 0.769
# }
# English Suite No. 1 in A Major, BWV 806: IX. Gigue: 78NvjLtG81xgPKFqgAl5oC
# 0
# {
#     "acousticness": 0.612,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/78NvjLtG81xgPKFqgAl5oC",
#     "danceability": 0.295,
#     "duration_ms": 85996,
#     "energy": 0.814,
#     "id": "78NvjLtG81xgPKFqgAl5oC",
#     "instrumentalness": 0.733,
#     "key": 1,
#     "liveness": 0.14,
#     "loudness": -13.734,
#     "mode": 1,
#     "speechiness": 0.0367,
#     "tempo": 96.582,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/78NvjLtG81xgPKFqgAl5oC",
#     "type": "audio_features",
#     "uri": "spotify:track:78NvjLtG81xgPKFqgAl5oC",
#     "valence": 0.964
# }
# Síguelo Bailando: 5Y9fnynLlIvqtM710MHzfz
# 71
# {
#     "acousticness": 0.165,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5Y9fnynLlIvqtM710MHzfz",
#     "danceability": 0.855,
#     "duration_ms": 226800,
#     "energy": 0.664,
#     "id": "5Y9fnynLlIvqtM710MHzfz",
#     "instrumentalness": 3.97e-05,
#     "key": 9,
#     "liveness": 0.0937,
#     "loudness": -7.11,
#     "mode": 0,
#     "speechiness": 0.0607,
#     "tempo": 98.015,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5Y9fnynLlIvqtM710MHzfz",
#     "type": "audio_features",
#     "uri": "spotify:track:5Y9fnynLlIvqtM710MHzfz",
#     "valence": 0.626
# }
# Quit (feat. Ariana Grande): 4rwqrKdwlFWJ6LvPYaOtgn
# 68
# {
#     "acousticness": 0.105,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4rwqrKdwlFWJ6LvPYaOtgn",
#     "danceability": 0.44,
#     "duration_ms": 258188,
#     "energy": 0.413,
#     "id": "4rwqrKdwlFWJ6LvPYaOtgn",
#     "instrumentalness": 3.4e-05,
#     "key": 0,
#     "liveness": 0.0997,
#     "loudness": -7.365,
#     "mode": 0,
#     "speechiness": 0.0407,
#     "tempo": 86.911,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/4rwqrKdwlFWJ6LvPYaOtgn",
#     "type": "audio_features",
#     "uri": "spotify:track:4rwqrKdwlFWJ6LvPYaOtgn",
#     "valence": 0.141
# }
# The Times They Are A-Changin': 52vA3CYKZqZVdQnzRrdZt6
# 68
# {
#     "acousticness": 0.887,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/52vA3CYKZqZVdQnzRrdZt6",
#     "danceability": 0.389,
#     "duration_ms": 192053,
#     "energy": 0.396,
#     "id": "52vA3CYKZqZVdQnzRrdZt6",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.0828,
#     "loudness": -7.999,
#     "mode": 1,
#     "speechiness": 0.0332,
#     "tempo": 171.86,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/52vA3CYKZqZVdQnzRrdZt6",
#     "type": "audio_features",
#     "uri": "spotify:track:52vA3CYKZqZVdQnzRrdZt6",
#     "valence": 0.585
# }
# Besos En Guerra: 7i8cN29xPG9h0ClT7IsJ26
# 8
# {
#     "acousticness": 0.126,
# ...
#     "danceability": 0.836,
#     "duration_ms": 213358,
#     "energy": 0.579,
#     "id": "3JAeYOjyJodI4PRs44lx2l",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.11,
#     "loudness": -6.164,
#     "mode": 1,
#     "speechiness": 0.243,
#     "tempo": 85.486,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3JAeYOjyJodI4PRs44lx2l",
#     "type": "audio_features",
#     "uri": "spotify:track:3JAeYOjyJodI4PRs44lx2l",
#     "valence": 0.431
# }
# Drift Away: 0RFgvrhkf9FiDRLA0BhzpZ
# 68
# {
#     "acousticness": 0.181,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0RFgvrhkf9FiDRLA0BhzpZ",
#     "danceability": 0.583,
#     "duration_ms": 255560,
#     "energy": 0.66,
#     "id": "0RFgvrhkf9FiDRLA0BhzpZ",
#     "instrumentalness": 0,
#     "key": 11,
#     "liveness": 0.0979,
#     "loudness": -5.078,
#     "mode": 1,
#     "speechiness": 0.0377,
#     "tempo": 151.956,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0RFgvrhkf9FiDRLA0BhzpZ",
#     "type": "audio_features",
#     "uri": "spotify:track:0RFgvrhkf9FiDRLA0BhzpZ",
#     "valence": 0.861
# }
# As I Am: 6hRrzZJ90DNQdEF1Wu2Mrf
# 62
# {
#     "acousticness": 0.0818,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/6hRrzZJ90DNQdEF1Wu2Mrf",
#     "danceability": 0.444,
#     "duration_ms": 240120,
#     "energy": 0.567,
#     "id": "6hRrzZJ90DNQdEF1Wu2Mrf",
#     "instrumentalness": 1.36e-06,
#     "key": 2,
#     "liveness": 0.225,
#     "loudness": -8.188,
#     "mode": 0,
#     "speechiness": 0.247,
#     "tempo": 83.661,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/6hRrzZJ90DNQdEF1Wu2Mrf",
#     "type": "audio_features",
#     "uri": "spotify:track:6hRrzZJ90DNQdEF1Wu2Mrf",
#     "valence": 0.172
# }
# Lord Pretty Flacko Jodye 2 (LPFJ2): 1j6kDJttn6wbVyMaM42Nxm
# 67
# {
#     "acousticness": 0.0122,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1j6kDJttn6wbVyMaM42Nxm",
#     "danceability": 0.489,
#     "duration_ms": 126960,
#     "energy": 0.718,
#     "id": "1j6kDJttn6wbVyMaM42Nxm",
#     "instrumentalness": 0,
#     "key": 6,
#     "liveness": 0.0546,
#     "loudness": -5.989,
#     "mode": 1,
#     "speechiness": 0.11,
#     "tempo": 207.986,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1j6kDJttn6wbVyMaM42Nxm",
#     "type": "audio_features",
#     "uri": "spotify:track:1j6kDJttn6wbVyMaM42Nxm",
#     "valence": 0.0568
# }
# Always: 3SxSrUogj4LpAkLKXeTtTQ
# 67
# {
#     "acousticness": 0.777,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3SxSrUogj4LpAkLKXeTtTQ",
#     "danceability": 0.669,
#     "duration_ms": 197333,
#     "energy": 0.374,
#     "id": "3SxSrUogj4LpAkLKXeTtTQ",
#     "instrumentalness": 0,
#     "key": 1,
#     "liveness": 0.326,
#     "loudness": -7.349,
#     "mode": 1,
#     "speechiness": 0.0385,
#     "tempo": 127.938,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3SxSrUogj4LpAkLKXeTtTQ",
#     "type": "audio_features",
#     "uri": "spotify:track:3SxSrUogj4LpAkLKXeTtTQ",
#     "valence": 0.394
# }
# Pouring Rain & Thunder: 4FO4ccOzpUP95P3sQBmbK9
# 68
# {
#     "acousticness": 0.000619,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4FO4ccOzpUP95P3sQBmbK9",
#     "danceability": 0.0781,
#     "duration_ms": 222819,
#     "energy": 0.383,
#     "id": "4FO4ccOzpUP95P3sQBmbK9",
#     "instrumentalness": 0.958,
#     "key": 2,
#     "liveness": 0.357,
#     "loudness": -22.909,
#     "mode": 1,
#     "speechiness": 0.0532,
#     "tempo": 84.229,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/4FO4ccOzpUP95P3sQBmbK9",
#     "type": "audio_features",
#     "uri": "spotify:track:4FO4ccOzpUP95P3sQBmbK9",
#     "valence": 0.0306
# }
# Other Friends (feat. Sarah Stiles, Zach Callison, Deedee Magno Hall, Estelle & Michaela Dietz): 30z2IlXuYkWxIjtXpD9C6a
# 63
# {
#     "acousticness": 0.137,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/30z2IlXuYkWxIjtXpD9C6a",
#     "danceability": 0.605,
#     "duration_ms": 167890,
#     "energy": 0.415,
#     "id": "30z2IlXuYkWxIjtXpD9C6a",
#     "instrumentalness": 0,
#     "key": 11,
#     "liveness": 0.346,
#     "loudness": -11.448,
#     "mode": 0,
#     "speechiness": 0.418,
#     "tempo": 118.032,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/30z2IlXuYkWxIjtXpD9C6a",
#     "type": "audio_features",
#     "uri": "spotify:track:30z2IlXuYkWxIjtXpD9C6a",
#     "valence": 0.384
# }
# fake smile: 3wFLWP0FcIqHK1wb1CPthQ
# 71
# {
#     "acousticness": 0.329,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3wFLWP0FcIqHK1wb1CPthQ",
#     "danceability": 0.45,
#     "duration_ms": 208880,
#     "energy": 0.619,
#     "id": "3wFLWP0FcIqHK1wb1CPthQ",
#     "instrumentalness": 0,
#     "key": 9,
#     "liveness": 0.319,
#     "loudness": -7.412,
#     "mode": 1,
#     "speechiness": 0.372,
#     "tempo": 83.3,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3wFLWP0FcIqHK1wb1CPthQ",
#     "type": "audio_features",
#     "uri": "spotify:track:3wFLWP0FcIqHK1wb1CPthQ",
#     "valence": 0.427
# }
# Plus tôt: 3ODEuZjfxec5fYnzVhxANv
# 64
# {
#     "acousticness": 0.964,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3ODEuZjfxec5fYnzVhxANv",
#     "danceability": 0.335,
#     "duration_ms": 179896,
#     "energy": 0.154,
#     "id": "3ODEuZjfxec5fYnzVhxANv",
#     "instrumentalness": 0.918,
#     "key": 2,
#     "liveness": 0.106,
#     "loudness": -20.918,
#     "mode": 1,
#     "speechiness": 0.0417,
#     "tempo": 133.951,
#     "time_signature": 1,
#     "track_href": "https://api.spotify.com/v1/tracks/3ODEuZjfxec5fYnzVhxANv",
#     "type": "audio_features",
#     "uri": "spotify:track:3ODEuZjfxec5fYnzVhxANv",
#     "valence": 0.186
# }
# Fine China: 5274I4mUMnYczyeXkGDWZN
# 78
# {
#     "acousticness": 0.0484,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/5274I4mUMnYczyeXkGDWZN",
#     "danceability": 0.656,
#     "duration_ms": 141587,
#     "energy": 0.542,
#     "id": "5274I4mUMnYczyeXkGDWZN",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.126,
#     "loudness": -7.358,
#     "mode": 1,
#     "speechiness": 0.323,
#     "tempo": 166.111,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/5274I4mUMnYczyeXkGDWZN",
#     "type": "audio_features",
#     "uri": "spotify:track:5274I4mUMnYczyeXkGDWZN",
#     "valence": 0.551
# }
# I Won't Say (I'm In Love): 0PKmDncVOiNQLO6D1P6PXi
# 60
# {
#     "acousticness": 0.228,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0PKmDncVOiNQLO6D1P6PXi",
#     "danceability": 0.684,
#     "duration_ms": 140227,
#     "energy": 0.481,
#     "id": "0PKmDncVOiNQLO6D1P6PXi",
#     "instrumentalness": 0,
#     "key": 0,
#     "liveness": 0.157,
#     "loudness": -10.305,
#     "mode": 1,
#     "speechiness": 0.0391,
#     "tempo": 121.208,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/0PKmDncVOiNQLO6D1P6PXi",
#     "type": "audio_features",
#     "uri": "spotify:track:0PKmDncVOiNQLO6D1P6PXi",
#     "valence": 0.48
# }
# En Menos de Un Minuto: 0laoKkCyhp5HW3wGejhPV5
# 65
# {
#     "acousticness": 0.554,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/0laoKkCyhp5HW3wGejhPV5",
#     "danceability": 0.702,
#     "duration_ms": 177714,
#     "energy": 0.621,
#     "id": "0laoKkCyhp5HW3wGejhPV5",
#     "instrumentalness": 0,
#     "key": 7,
#     "liveness": 0.226,
#     "loudness": -6.884,
#     "mode": 1,
#     "speechiness": 0.0296,
#     "tempo": 114.532,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/0laoKkCyhp5HW3wGejhPV5",
#     "type": "audio_features",
#     "uri": "spotify:track:0laoKkCyhp5HW3wGejhPV5",
#     "valence": 0.581
# }
# Oceans Outside: 4ndb9Sv5pTIolY8Lt5jmSn
# 61
# {
#     "acousticness": 0.681,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/4ndb9Sv5pTIolY8Lt5jmSn",
#     "danceability": 0.117,
#     "duration_ms": 122042,
#     "energy": 0.0467,
#     "id": "4ndb9Sv5pTIolY8Lt5jmSn",
#     "instrumentalness": 0.973,
#     "key": 1,
#     "liveness": 0.584,
#     "loudness": -16.515,
#     "mode": 1,
#     "speechiness": 0.319,
#     "tempo": 85.433,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/4ndb9Sv5pTIolY8Lt5jmSn",
#     "type": "audio_features",
#     "uri": "spotify:track:4ndb9Sv5pTIolY8Lt5jmSn",
#     "valence": 1e-05
# }
# OMG (feat. will.i.am): 1bM50INir8voAkVoKuvEUI
# 70
# {
#     "acousticness": 0.198,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1bM50INir8voAkVoKuvEUI",
#     "danceability": 0.781,
#     "duration_ms": 269493,
#     "energy": 0.745,
#     "id": "1bM50INir8voAkVoKuvEUI",
#     "instrumentalness": 1.14e-05,
#     "key": 4,
#     "liveness": 0.36,
#     "loudness": -5.81,
#     "mode": 0,
#     "speechiness": 0.0332,
#     "tempo": 129.998,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/1bM50INir8voAkVoKuvEUI",
#     "type": "audio_features",
#     "uri": "spotify:track:1bM50INir8voAkVoKuvEUI",
#     "valence": 0.326
# }
# Stronger Than You: 3ry3QOTArZPVqduQETTX4m
# 61
# {
#     "acousticness": 0.126,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3ry3QOTArZPVqduQETTX4m",
#     "danceability": 0.727,
#     "duration_ms": 172636,
#     "energy": 0.543,
#     "id": "3ry3QOTArZPVqduQETTX4m",
#     "instrumentalness": 0,
#     "key": 8,
#     "liveness": 0.122,
#     "loudness": -7.18,
#     "mode": 1,
#     "speechiness": 0.053,
#     "tempo": 97.93,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3ry3QOTArZPVqduQETTX4m",
#     "type": "audio_features",
#     "uri": "spotify:track:3ry3QOTArZPVqduQETTX4m",
#     "valence": 0.482
# }
# Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit: 2Foc5Q5nqNiosCNqttzHof
# 75
# {
#     "acousticness": 0.0426,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2Foc5Q5nqNiosCNqttzHof",
#     "danceability": 0.794,
#     "duration_ms": 248413,
#     "energy": 0.811,
#     "id": "2Foc5Q5nqNiosCNqttzHof",
#     "instrumentalness": 1.07e-06,
#     "key": 6,
#     "liveness": 0.101,
#     "loudness": -8.966,
#     "mode": 0,
#     "speechiness": 0.038,
#     "tempo": 116.047,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2Foc5Q5nqNiosCNqttzHof",
#     "type": "audio_features",
#     "uri": "spotify:track:2Foc5Q5nqNiosCNqttzHof",
#     "valence": 0.862
# }
# Passion: 3WbPxUvKl4DGcTRHgYWiyJ
# 3
# {
#     "acousticness": 0.0212,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/3WbPxUvKl4DGcTRHgYWiyJ",
#     "danceability": 0.692,
#     "duration_ms": 333200,
#     "energy": 0.525,
#     "id": "3WbPxUvKl4DGcTRHgYWiyJ",
#     "instrumentalness": 0.0019,
#     "key": 9,
#     "liveness": 0.0944,
#     "loudness": -12.691,
#     "mode": 1,
#     "speechiness": 0.0373,
#     "tempo": 103.679,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/3WbPxUvKl4DGcTRHgYWiyJ",
#     "type": "audio_features",
#     "uri": "spotify:track:3WbPxUvKl4DGcTRHgYWiyJ",
#     "valence": 0.0879
# }
# Ordinary People: 2ZA4uMlSZjaoWGFqP1tsLI
# 68
# {
#     "acousticness": 0.929,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2ZA4uMlSZjaoWGFqP1tsLI",
#     "danceability": 0.469,
#     "duration_ms": 281467,
#     "energy": 0.132,
#     "id": "2ZA4uMlSZjaoWGFqP1tsLI",
#     "instrumentalness": 0,
#     "key": 10,
#     "liveness": 0.0873,
#     "loudness": -14.001,
#     "mode": 1,
#     "speechiness": 0.0807,
#     "tempo": 67.011,
#     "time_signature": 3,
#     "track_href": "https://api.spotify.com/v1/tracks/2ZA4uMlSZjaoWGFqP1tsLI",
#     "type": "audio_features",
#     "uri": "spotify:track:2ZA4uMlSZjaoWGFqP1tsLI",
#     "valence": 0.36
# }
# Oh Ana: 2ag28zkxul9hTpi5ksQLRp
# 60
# {
#     "acousticness": 0.672,
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/2ag28zkxul9hTpi5ksQLRp",
#     "danceability": 0.512,
#     "duration_ms": 197080,
#     "energy": 0.525,
#     "id": "2ag28zkxul9hTpi5ksQLRp",
#     "instrumentalness": 1.66e-05,
#     "key": 5,
#     "liveness": 0.112,
#     "loudness": -7.152,
#     "mode": 1,
#     "speechiness": 0.0429,
#     "tempo": 128.054,
#     "time_signature": 4,
#     "track_href": "https://api.spotify.com/v1/tracks/2ag28zkxul9hTpi5ksQLRp",
#     "type": "audio_features",
#     "uri": "spotify:track:2ag28zkxul9hTpi5ksQLRp",
#     "valence": 0.337
# }
# [{'track_name': 'Nobody', 'track_id': '2qfEcCkEo5NscA9GL7ER72', 'popularity': 76, 'danceability': 0.673, 'energy': 0.687, 'key': 6, 'loudness': -5.295, 'mode': 0, 'speechiness': 0.0623, 'acousticness': 0.269, 'instrumentalness': 0, 'liveness': 0.181, 'valence': 0.524, 'tempo': 96.964, 'duration_ms': 211040, 'time_signature': 4}, {'track_name': 'Lost in the Middle of Nowhere (feat. Becky G)', 'track_id': '5KfKPfX5cZvOuHoy9io65A', 'popularity': 61, 'danceability': 0.559, 'energy': 0.754, 'key': 6, 'loudness': -5.344, 'mode': 0, 'speechiness': 0.0481, 'acousticness': 0.00184, 'instrumentalness': 0.000462, 'liveness': 0.0366, 'valence': 0.438, 'tempo': 85.993, 'duration_ms': 188920, 'time_signature': 4}, {'track_name': "Look At Me Now (feat. Lil' Wayne & Busta Rhymes)", 'track_id': '3hsmbFKT5Cujb5GQjqEU39', 'popularity': 71, 'danceability': 0.767, 'energy': 0.677, 'key': 11, 'loudness': -6.128, 'mode': 0, 'speechiness': 0.184, 'acousticness': 0.0339, 'instrumentalness': 5.51e-06, 'liveness': 0.144, 'valence': 0.538, 'tempo': 146.155, 'duration_ms': 222587, 'time_signature': 4}, {'track_name': 'Futsal Shuffle 2020', 'track_id': '2Ec33AVlkTTq8BHFgBTdQs', 'popularity': 85, 'danceability': 0.881, 'energy': 0.457, 'key': 7, 'loudness': -8.191, 'mode': 0, 'speechiness': 0.156, 'acousticness': 0.0327, 'instrumentalness': 0, 'liveness': 0.231, 'valence': 0.296, 'tempo': 136.97, 'duration_ms': 198913, 'time_signature': 4}, {'track_name': 'Heart Of Glass - Special Mix', 'track_id': '0a4agFmqHXxcZl1nho1BxM', 'popularity': 69, 'danceability': 0.694, 'energy': 0.577, 'key': 4, 'loudness': -14.63, 'mode': 1, 'speechiness': 0.0308, 'acousticness': 0.015, 'instrumentalness': 0.00836, 'liveness': 0.0853, 'valence': 0.845, 'tempo': 114.478, 'duration_ms': 275733, 'time_signature': 4}, {'track_name': 'Sonata in C Major, BWW 966: I. Praeludium', 'track_id': '0U7oxeg9xWG8hyRWiKYriY', 'popularity': 7, 'danceability': 0.368, 'energy': 0.378, 'key': 11, 'loudness': -17.274, 'mode': 1, 'speechiness': 0.0383, 'acousticness': 0.867, 'instrumentalness': 0.859, 'liveness': 0.078, 'valence': 0.482, 'tempo': 61.35, 'duration_ms': 105040, 'time_signature': 3}, {'track_name': "If You're Gonna Lie", 'track_id': '0mPTZjG5PElXTUIxj1nqgp', 'popularity': 64, 'danceability': 0.671, 'energy': 0.763, 'key': 8, 'loudness': -5.877, 'mode': 1, 'speechiness': 0.305, 'acousticness': 0.607, 'instrumentalness': 2.16e-05, 'liveness': 0.495, 'valence': 0.469, 'tempo': 149.87, 'duration_ms': 203113, 'time_signature': 4}, {'track_name': 'Sex on Fire', 'track_id': '0ntQJM78wzOLVeCUAW7Y45', 'popularity': 78, 'danceability': 0.542, 'energy': 0.905, 'key': 9, 'loudness': -5.653, 'mode': 1, 'speechiness': 0.054, 'acousticness': 0.00172, 'instrumentalness': 0.0104, 'liveness': 0.136, 'valence': 0.374, 'tempo': 153.398, 'duration_ms': 203347, 'time_signature': 4}, {'track_name': 'Unmeltable Me - Outtake', 'track_id': '09MvGKcju2jf2ktxDa0s17', 'popularity': 59, 'danceability': 0.685, 'energy': 0.435, 'key': 0, 'loudness': -8.804, 'mode': 1, 'speechiness': 0.622, 'acousticness': 0.402, 'instrumentalness': 0, 'liveness': 0.312, 'valence': 0.765, 'tempo': 79.168, 'duration_ms': 85306, 'time_signature': 4}, {'track_name': 'How U Feel', 'track_id': '7CWiWkccuRRdrmaW6AjVEf', 'popularity': 57, 'danceability': 0.86, 'energy': 0.799, 'key': 2, 'loudness': -2.446, 'mode': 1, 'speechiness': 0.149, 'acousticness': 0.0532, 'instrumentalness': 2.54e-05, 'liveness': 0.369, 'valence': 0.491, 'tempo': 140.005, 'duration_ms': 205682, 'time_signature': 4}, {'track_name': 'Kiss It Better', 'track_id': '0UHB9METy4VCXNgkcGqHqS', 'popularity': 68, 'danceability': 0.619, 'energy': 0.806, 'key': 3, 'loudness': -4.8, 'mode': 0, 'speechiness': 0.0483, 'acousticness': 0.272, 'instrumentalness': 0, 'liveness': 0.0671, 'valence': 0.877, 'tempo': 95.0, 'duration_ms': 253080, 'time_signature': 4}, {'track_name': 'Forever Young', 'track_id': '56bHclo7YNvpujMveLElQn', 'popularity': 66, 'danceability': 0.6, 'energy': 0.96,  ...

# %%
control_sample_list_df = pd.DataFrame(control_sample_list)
print(control_sample_list_df.head())
# Out:
#                                          track_name                track_id  \
# 0                                            Nobody  2qfEcCkEo5NscA9GL7ER72
# 1     Lost in the Middle of Nowhere (feat. Becky G)  5KfKPfX5cZvOuHoy9io65A
# 2  Look At Me Now (feat. Lil' Wayne & Busta Rhymes)  3hsmbFKT5Cujb5GQjqEU39
# 3                               Futsal Shuffle 2020  2Ec33AVlkTTq8BHFgBTdQs
# 4                      Heart Of Glass - Special Mix  0a4agFmqHXxcZl1nho1BxM
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          76         0.673   0.687    6    -5.295     0       0.0623
# 1          61         0.559   0.754    6    -5.344     0       0.0481
# 2          71         0.767   0.677   11    -6.128     0       0.1840
# 3          85         0.881   0.457    7    -8.191     0       0.1560
# 4          69         0.694   0.577    4   -14.630     1       0.0308
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.26900          0.000000    0.1810    0.524   96.964       211040
# 1       0.00184          0.000462    0.0366    0.438   85.993       188920
# 2       0.03390          0.000006    0.1440    0.538  146.155       222587
# 3       0.03270          0.000000    0.2310    0.296  136.970       198913
# 4       0.01500          0.008360    0.0853    0.845  114.478       275733
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# clean up data and display in a table
df_clean = control_sample_list_df[['track_name', 'track_id', 'popularity','danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']].copy()
df_clean
# Out:
#                                             track_name  \
# 0                                               Nobody
# 1        Lost in the Middle of Nowhere (feat. Becky G)
# 2     Look At Me Now (feat. Lil' Wayne & Busta Rhymes)
# 3                                  Futsal Shuffle 2020
# 4                         Heart Of Glass - Special Mix
# ..                                                 ...
# 192                                  Stronger Than You
# 193  Get Lucky (feat. Pharrell Williams & Nile Rodg...
# 194                                            Passion
# 195                                    Ordinary People
# 196                                             Oh Ana
#
#                    track_id  popularity  danceability  energy  key  loudness  \
# 0    2qfEcCkEo5NscA9GL7ER72          76         0.673   0.687    6    -5.295
# 1    5KfKPfX5cZvOuHoy9io65A          61         0.559   0.754    6    -5.344
# 2    3hsmbFKT5Cujb5GQjqEU39          71         0.767   0.677   11    -6.128
# 3    2Ec33AVlkTTq8BHFgBTdQs          85         0.881   0.457    7    -8.191
# 4    0a4agFmqHXxcZl1nho1BxM          69         0.694   0.577    4   -14.630
# ..                      ...         ...           ...     ...  ...       ...
# 192  3ry3QOTArZPVqduQETTX4m          61         0.727   0.543    8    -7.180
# 193  2Foc5Q5nqNiosCNqttzHof          75         0.794   0.811    6    -8.966
# 194  3WbPxUvKl4DGcTRHgYWiyJ           3         0.692   0.525    9   -12.691
# 195  2ZA4uMlSZjaoWGFqP1tsLI          68         0.469   0.132   10   -14.001
# 196  2ag28zkxul9hTpi5ksQLRp          60         0.512   0.525    5    -7.152
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0       0       0.0623       0.26900          0.000000    0.1810   0.5240
# 1       0       0.0481       0.00184          0.000462    0.0366   0.4380
# 2       0       0.1840       0.03390          0.000006    0.1440   0.5380
# 3       0       0.1560       0.03270          0.000000    0.2310   0.2960
# 4       1       0.0308       0.01500          0.008360    0.0853   0.8450
# ..    ...          ...           ...               ...       ...      ...
# 192     1       0.0530       0.12600          0.000000    0.1220   0.4820
# 193     0       0.0380       0.04260          0.000001    0.1010   0.8620
# 194     1       0.0373       0.02120          0.001900    0.0944   0.0879
# 195     1       0.0807       0.92900          0.000000    0.0873   0.3600
# 196     1       0.0429       0.67200          0.000017    0.1120   0.3370
#
#        tempo  duration_ms  time_signature
# 0     96.964       211040               4
# 1     85.993       188920               4
# 2    146.155       222587               4
# 3    136.970       198913               4
# 4    114.478       275733               4
# ..       ...          ...             ...
# 192   97.930       172636               4
# 193  116.047       248413               4
# 194  103.679       333200               4
# 195   67.011       281467               3
# 196  128.054       197080               4
#
# [197 rows x 16 columns]

# %%
# Plot out energy versus loudness
loudness_values = df_clean['energy']
energy_values = df_clean['loudness']
plt.scatter(energy_values,loudness_values)
plt.xlabel('energy')
plt.ylabel('loudness')
plt.show()

# %%
summary_df_mean = averages_summary(df_clean, 'mean')
print(summary_df_mean)
# Out:
#    danceability    energy      key  loudness      mode  speechiness  \
# 0      0.613046  0.641736  5.13198    -7.523  0.680203     0.107153
#
#    acousticness  instrumentalness  liveness       tempo  valence  \
# 0      0.251635          0.061923  0.194152  124.171701  0.49562
#
#      duration_ms  time_signature
# 0  222526.654822        3.878173

# %%
summary_df_median = averages_summary(df_clean, 'median')
print(summary_df_median)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.613   0.675  5.0    -6.508   1.0       0.0602         0.125
#
#    instrumentalness  liveness    tempo  valence  duration_ms  time_signature
# 0          0.000002     0.132  127.661    0.492     211000.0             4.0

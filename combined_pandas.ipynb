# %%
# Dependencies and Setup
import numpy as np
import requests
import json
import time
import requests
import pandas as pd
import numpy as np


from pandas.io.json import json_normalize
from pprint import pprint
from apiCallObjects import topOneHundred
from apiCallObjects import attributesObject
from apiCallObjects import compiledAPIcall

# %%
response_list = compiledAPIcall
popularity =[]
jreq = topOneHundred
for response in jreq['tracks']['items']:
    p = response['track']['popularity']
    popularity.append(p)
#print(popularity)

results_df = pd.DataFrame(response_list)
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_seq_items = None
danceability = [item["danceability"] for  item in attributesObject ]
results_df['danceability'] = danceability

# %%
results_df['danceability'] = [item["danceability"] for  item in attributesObject ]
results_df['energy'] = [item["energy"] for  item in attributesObject ]
results_df['key'] = [item["key"] for  item in attributesObject ]
results_df['loudness'] = [item["loudness"] for  item in attributesObject ]
results_df['mode'] = [item["mode"] for  item in attributesObject ]
results_df['speechiness'] = [item["speechiness"] for  item in attributesObject ]
results_df['acousticness'] = [item["acousticness"] for  item in attributesObject ]
results_df['instrumentalness'] = [item["instrumentalness"] for  item in attributesObject ]
results_df['liveness'] = [item["liveness"] for  item in attributesObject ]
results_df['valence'] = [item["valence"] for  item in attributesObject ]
results_df['tempo'] = [item["tempo"] for  item in attributesObject ]
results_df['duration_ms'] = [item["duration_ms"] for  item in attributesObject ]
results_df['time_signature'] = [item["time_signature"] for  item in attributesObject ]

print(results_df["response"])

pprint(results_df.head())
# Out:
# 0     {'danceability': 0.694, 'energy': 0.815, 'key'...
# 1     {'danceability': 0.599, 'energy': 0.667, 'key'...
# 2     {'danceability': 0.825, 'energy': 0.652, 'key'...
# 3     {'danceability': 0.908, 'energy': 0.621, 'key'...
# 4     {'danceability': 0.833, 'energy': 0.434, 'key'...
# 5     {'danceability': 0.617, 'energy': 0.635, 'key'...
# 6     {'danceability': 0.679, 'energy': 0.634, 'key'...
# 7     {'danceability': 0.64, 'energy': 0.533, 'key':...
# 8     {'danceability': 0.696, 'energy': 0.817, 'key'...
# 9     {'danceability': 0.565, 'energy': 0.782, 'key'...
# 10    {'danceability': 0.857, 'energy': 0.8, 'key': ...
# 11    {'danceability': 0.853, 'energy': 0.56, 'key':...
# 12    {'danceability': 0.707, 'energy': 0.629, 'key'...
# 13    {'danceability': 0.66, 'energy': 0.786, 'key':...
# 14    {'danceability': 0.774, 'energy': 0.626, 'key'...
# 15    {'danceability': 0.809, 'energy': 0.463, 'key'...
# 16    {'danceability': 0.516, 'energy': 0.595, 'key'...
# 17    {'danceability': 0.732, 'energy': 0.75, 'key':...
# 18    {'danceability': 0.633, 'energy': 0.592, 'key'...
# 19    {'danceability': 0.755, 'energy': 0.789, 'key'...
# 20    {'danceability': 0.726, 'energy': 0.769, 'key'...
# 21    {'danceability': 0.638, 'energy': 0.523, 'key'...
# 22    {'danceability': 0.683, 'energy': 0.427, 'key'...
# 23    {'danceability': 0.584, 'energy': 0.54, 'key':...
# 24    {'danceability': 0.624, 'energy': 0.876, 'key'...
# 25    {'danceability': 0.736, 'energy': 0.795, 'key'...
# 26    {'danceability': 0.63, 'energy': 0.804, 'key':...
# 27    {'danceability': 0.741, 'energy': 0.667, 'key'...
# 28    {'danceability': 0.62, 'energy': 0.574, 'key':...
# 29    {'danceability': 0.601, 'energy': 0.834, 'key'...
# 30    {'danceability': 0.684, 'energy': 0.823, 'key'...
# 31    {'danceability': 0.703, 'energy': 0.868, 'key'...
# 32    {'danceability': 0.746, 'energy': 0.794, 'key'...
# 33    {'danceability': 0.696, 'energy': 0.503, 'key'...
# 34    {'danceability': 0.746, 'energy': 0.653, 'key'...
# 35    {'danceability': 0.565, 'energy': 0.771, 'key'...
# 36    {'danceability': 0.67, 'energy': 0.585, 'key':...
# 37    {'danceability': 0.77, 'energy': 0.787, 'key':...
# 38    {'danceability': 0.736, 'energy': 0.449, 'key'...
# 39    {'danceability': 0.72, 'energy': 0.763, 'key':...
# 40    {'danceability': 0.653, 'energy': 0.658, 'key'...
# 41    {'danceability': 0.67, 'energy': 0.838, 'key':...
# 42    {'danceability': 0.754, 'energy': 0.762, 'key'...
# 43    {'danceability': 0.735, 'energy': 0.451, 'key'...
# 44    {'danceability': 0.703, 'energy': 0.715, 'key'...
# 45    {'danceability': 0.8, 'energy': 0.585, 'key': ...
# 46    {'danceability': 0.773, 'energy': 0.819, 'key'...
# 47    {'danceability': 0.683, 'energy': 0.691, 'key'...
# 48    {'danceability': 0.887, 'energy': 0.669, 'key'...
# 49    {'danceability': 0.728, 'energy': 0.426, 'key'...
# 50    {'danceability': 0.744, 'energy': 0.836, 'key'...
# 51    {'danceability': 0.797, 'energy': 0.791, 'key'...
# 52    {'danceability': 0.747, 'energy': 0.864, 'key'...
# 53    {'danceability': 0.358, 'energy': 0.557, 'key'...
# 54    {'danceability': 0.925, 'energy': 0.443, 'key'...
# 55    {'danceability': 0.658, 'energy': 0.535, 'key'...
# 56    {'danceability': 0.708, 'energy': 0.693, 'key'...
# 57    {'danceability': 0.443, 'energy': 0.369, 'key'...
# 58    {'danceability': 0.841, 'energy': 0.639, 'key'...
# 59    {'danceability': 0.489, 'energy': 0.962, 'key'...
# 60    {'danceability': 0.427, 'energy': 0.262, 'key'...
# 61    {'danceability': 0.748, 'energy': 0.524, 'key'...
# 62    {'danceability': 0.461, 'energy': 0.834, 'key'...
# 63    {'danceability': 0.497, 'energy': 0.489, 'key'...
# 64    {'danceability': 0.748, 'energy': 0.627, 'key'...
# 65    {'danceability': 0.748, 'energy': 0.705, 'key'...
# 66    {'danceability': 0.755, 'energy': 0.57, 'key':...
# 67    {'danceability': 0.859, 'energy': 0.756, 'key'...
# 68    {'danceability': 0.841, 'energy': 0.728, 'key'...
# 69    {'danceability': 0.681, 'energy': 0.594, 'key'...
# 70    {'danceability': 0.415, 'energy': 0.369, 'key'...
# 71    {'danceability': 0.889, 'energy': 0.853, 'key'...
# 72    {'danceability': 0.599, 'energy': 0.448, 'key'...
# 73    {'danceability': 0.927, 'energy': 0.665, 'key'...
# 74    {'danceability': 0.791, 'energy': 0.619, 'key'...
# 75    {'danceability': 0.732, 'energy': 0.458, 'key'...
# 76    {'danceability': 0.623, 'energy': 0.654, 'key'...
# 77    {'danceability': 0.792, 'energy': 0.819, 'key'...
# 78    {'danceability': 0.446, 'energy': 0.793, 'key'...
# 79    {'danceability': 0.928, 'energy': 0.481, 'key'...
# 80    {'danceability': 0.76, 'energy': 0.303, 'key':...
# 81    {'danceability': 0.78, 'energy': 0.574, 'key':...
# 82    {'danceability': 0.92, 'energy': 0.674, 'key':...
# 83    {'danceability': 0.476, 'energy': 0.718, 'key'...
# 84    {'danceability': 0.832, 'energy': 0.772, 'key'...
# 85    {'danceability': 0.607, 'energy': 0.718, 'key'...
# 86    {'danceability': 0.763, 'energy': 0.726, 'key'...
# 87    {'danceability': 0.745, 'energy': 0.595, 'key'...
# 88    {'danceability': 0.685, 'energy': 0.859, 'key'...
# 89    {'danceability': 0.365, 'energy': 0.413, 'key'...
# 90    {'danceability': 0.71, 'energy': 0.73, 'key': ...
# 91    {'danceability': 0.636, 'energy': 0.633, 'key'...
# 92    {'danceability': 0.672, 'energy': 0.642, 'key'...
# 93    {'danceability': 0.745, 'energy': 0.356, 'key'...
# 94    {'danceability': 0.61, 'energy': 0.712, 'key':...
# 95    {'danceability': 0.818, 'energy': 0.803, 'key'...
# 96    {'danceability': 0.735, 'energy': 0.482, 'key'...
# 97    {'danceability': 0.865, 'energy': 0.687, 'key'...
# 98    {'danceability': 0.639, 'energy': 0.869, 'key'...
# 99    {'danceability': 0.87, 'energy': 0.502, 'key':...
# Name: response, dtype: object
#           track_name                track_id  \
# 0  Despacito - Remix  5CtI0qwDJkDQGwXD1H1cLb
# 1        I'm the One  72Q0FQQo32KJloivv5xge2
# 2       Shape of You  7qiZfU4dY1lWllzX7mPBI3
# 3            HUMBLE.  7KXjTSCq5nL1LoYtL7XAwS
# 4           Mask Off  3rOSwuTsUlJp0Pu0MkN8r8
#
#                                             response  danceability  energy  \
# 0  {'danceability': 0.694, 'energy': 0.815, 'key'...         0.694   0.815
# 1  {'danceability': 0.599, 'energy': 0.667, 'key'...         0.599   0.667
# 2  {'danceability': 0.825, 'energy': 0.652, 'key'...         0.825   0.652
# 3  {'danceability': 0.908, 'energy': 0.621, 'key'...         0.908   0.621
# 4  {'danceability': 0.833, 'energy': 0.434, 'key'...         0.833   0.434
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    2    -4.328     1       0.1200      0.229000          0.000000    0.0924
# 1    7    -4.267     1       0.0367      0.053300          0.000000    0.1340
# 2    1    -3.183     0       0.0802      0.581000          0.000000    0.0931
# 3    1    -6.638     0       0.1020      0.000282          0.000054    0.0958
# 4    2    -8.795     1       0.4310      0.010200          0.021900    0.1650
#
#    valence    tempo  duration_ms  time_signature
# 0    0.813   88.931       228827               4
# 1    0.817   80.984       288877               4
# 2    0.931   95.977       233713               4
# 3    0.421  150.011       177000               4
# 4    0.281  150.062       204600               4
